# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !pip install tensorflow==1.12
# Out:
# Collecting tensorflow==1.12
#   Downloading https://files.pythonhosted.org/packages/22/cc/ca70b78087015d21c5f3f93694107f34ebccb3be9624385a911d4b52ecef/tensorflow-1.12.0-cp36-cp36m-manylinux1_x86_64.whl (83.1MB)
#      |████████████████████████████████| 83.1MB 300kB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (1.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (1.1.0)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (0.7.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (0.8.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (0.33.4)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (0.2.2)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (1.16.4)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (3.7.1)
# Collecting tensorboard<1.13.0,>=1.12.0 (from tensorflow==1.12)
#   Downloading https://files.pythonhosted.org/packages/07/53/8d32ce9471c18f8d99028b7cef2e5b39ea8765bd7ef250ca05b490880971/tensorboard-1.12.2-py3-none-any.whl (3.0MB)
#      |████████████████████████████████| 3.1MB 36.1MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (1.15.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (1.12.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (1.0.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==1.12) (41.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow==1.12) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.10 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow==1.12) (0.15.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow==1.12) (2.8.0)
# Installing collected packages: tensorboard, tensorflow
#   Found existing installation: tensorboard 1.14.0
#     Uninstalling tensorboard-1.14.0:
#       Successfully uninstalled tensorboard-1.14.0
#   Found existing installation: tensorflow 1.14.0
#     Uninstalling tensorflow-1.14.0:
#       Successfully uninstalled tensorflow-1.14.0
# Successfully installed tensorboard-1.12.2 tensorflow-1.12.0

# %%
import os
from io import BytesIO
from PIL import Image

import cv2
import tensorflow as tf

def del_all_flags(FLAGS):
    flags_dict = FLAGS._flags()    
    keys_list = [keys for keys in flags_dict]    
    for keys in keys_list:
        FLAGS.__delattr__(keys)

del_all_flags(tf.flags.FLAGS)


FLAGS = tf.app.flags
FLAGS.DEFINE_string('data_dir',
                    '/content/gdrive/My Drive/dataset',
                    'Path to the input data')
FLAGS.DEFINE_string('train_output_path',
                    'train.tfrecord',
                    'Path to output train TFRecord')
FLAGS.DEFINE_string('eval_output_path',
                    'eval.tfrecord',
                    'Path to output eval TFRecord')
FLAGS.DEFINE_float(
    'train_eval_split_factor', 0.75,
    'use this factor to split the train (default 3/4) and '
    'eval data (default 1/4) in data_dir')
FLAGS.DEFINE_integer('width', 120, 'customize image width')
FLAGS.DEFINE_integer('height', 100, 'customize image height')
FLAGS.DEFINE_integer('channel', 3, 'image color channel')
FLAGS.DEFINE_integer('skip_frames', 10,
                     'the number of frames we skip when we process the video')
FLAGS.DEFINE_integer('num_frames_per_clip', 16,
                     'the number of frames for a video clip')
FLAGS = FLAGS.FLAGS



def get_clips(image_list):
    # Given a list of images, return video clips of (num_frames_per_clip) consecutive frames as a list.
    video_clips = []
    images_len = len(image_list)
    if images_len < FLAGS.num_frames_per_clip:
        return video_clips

    # Prepare the first clip
    video_clips.append(image_list[:FLAGS.num_frames_per_clip])

    num_of_extra_clip = int(
        (images_len - FLAGS.num_frames_per_clip) / FLAGS.skip_frames)
    for i in range(1, num_of_extra_clip + 1):
        start = i * FLAGS.skip_frames - 1
        end = start + FLAGS.num_frames_per_clip
        video_clips.append(image_list[start:end])

    return video_clips

def process_dataset(train_writer, eval_writer, data_dir):
    label = 0
    # [class1, class2, class3, ..., class n]
    for class_dir in os.listdir(data_dir):
        class_path = os.path.join(data_dir, class_dir)
        if os.path.isdir(class_path):
            # Set the label value for this class, start from 0
            label += 1
            print("Processing class: " + str(label))
            # Process each video file in this class
            video_filenames = os.listdir(class_path)
            for video_filename in video_filenames[0:75]:
                process_video(train_writer, class_path, video_filename, label)
            for video_filename in video_filenames[76:100]:
                process_video(eval_writer, class_path, video_filename, label)


def process_video(writer, class_path, video_filename, label):
    video_filename_path = os.path.join(class_path, video_filename)
    if video_filename_path.endswith('mp4'):
        video_clips = _convert_video_to_clips(video_filename_path)
        # Convert the clip to tf record
        for clip in video_clips:
            tf_example = create_tf_example(raw=clip, label=label)
            writer.write(tf_example.SerializeToString())


def _convert_video_to_clips(video_path):
    # Use opencv to read video to list of images
    video_images_list = []
    cap = cv2.VideoCapture(video_path)
    while cap.isOpened():
        # frame shape [height, width, channel]
        _, frame = cap.read()
        try:
            # pil_image shape [width, height, channel]
            pil_image = Image.fromarray(frame)
            # Resize the image and convert the image according to the channel information
            if FLAGS.channel == 1:
                pil_image = pil_image.resize((FLAGS.width, FLAGS.height),
                                             Image.NEAREST).convert('L')
            else:
                pil_image = pil_image.resize((FLAGS.width, FLAGS.height),
                                             Image.NEAREST)
            # Encode the image to JPEG
            with BytesIO() as buffer:
                pil_image.save(buffer, format="JPEG")
                video_images_list.append(buffer.getvalue())
        except AttributeError:
            # Fail to read the image
            break

    # Convert list of images to clips of images with type np.float32
    return get_clips(image_list=video_images_list)


def _bytelist_feature(value):
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=value))


def _bytes_feature(value):
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=value))


def _int64_feature(value):
    return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))


def create_tf_example(raw, label):
    return tf.train.Example(
        features=tf.train.Features(
            feature={
                'clip/width': _int64_feature(FLAGS.width),
                'clip/height': _int64_feature(FLAGS.height),
                'clip/channel': _int64_feature(FLAGS.channel),
                'clip/raw': _bytelist_feature(raw),
                'clip/label': _int64_feature(label)
            }))


def get_total_video_clip_number(data_path):
    count = 0
    for _ in tf.python_io.tf_record_iterator(data_path):
        count += 1
    return count


def main(_):
    # Write the dataset
    train_writer = tf.python_io.TFRecordWriter(FLAGS.train_output_path)
    eval_writer = tf.python_io.TFRecordWriter(FLAGS.eval_output_path)

    process_dataset(
        train_writer=train_writer,
        eval_writer=eval_writer,
        data_dir=FLAGS.data_dir)

    train_writer.close()
    eval_writer.close()

    # Count the dataset record
    print("Total clips in train dataset: " +
          str(get_total_video_clip_number(FLAGS.train_output_path)))
    print("Total clips in eval dataset: " +
          str(get_total_video_clip_number(FLAGS.eval_output_path)))


#if __name__ == '__main__':
#    tf.app.run()

# %%
class DenseNet3D(object):
    """3D DenseNet Model class"""

    def __init__(
            self,
            video_clips,  # Shape: [batch_size, sequence_length, height, width, channels]
            labels,  # Shape: [batch_size, num_classes] 
            initial_learning_rate,
            decay_step,
            lr_decay_factor,
            num_classes,
            growth_rate,
            network_depth,
            total_blocks,
            keep_prob,
            weight_decay,
            reduction,
            bc_mode=False,
            **kwargs):
        self.video_clips = video_clips
        self.labels = labels
        self.num_classes = num_classes
        self.growth_rate = growth_rate
        self.network_depth = network_depth

        # How many features will be received after first convolution value
        self.first_output_features = growth_rate * 2

        self.total_blocks = total_blocks
        self.layers_per_block = (network_depth -
                                 (total_blocks + 1)) // total_blocks

        # Compression rate at the transition layers
        self.reduction = reduction
        self.bc_mode = bc_mode
        if not bc_mode:
            self.reduction = 1.0
            print(
                "Build 3D DenseNet model with %d blocks, %d composite layers each."
                % (total_blocks, self.layers_per_block))

        if bc_mode:
            self.layers_per_block = self.layers_per_block // 2
            print(
                "Build 3D DenseNet-BC model with %d blocks, %d bottleneck layers and %d composite layers each."
                % (total_blocks, self.layers_per_block, self.layers_per_block))

        self.keep_prob = keep_prob
        self.weight_decay = weight_decay
        self._is_training = tf.convert_to_tensor(True)

        # Initialize the global step
        self.global_step = tf.train.get_or_create_global_step()

        self.learning_rate = tf.train.exponential_decay(
            initial_learning_rate,
            self.global_step,
            decay_step,
            lr_decay_factor,
            staircase=True)

        self._build_graph()

    def _build_graph(self):
        # First convolution layer
        with tf.variable_scope('Initial_convolution'):
            output = self._conv3d(
                self.video_clips,
                out_features_count=self.first_output_features,
                kernel_size=7,
                strides=[1, 1, 2, 2, 1])
            output = self._pool(output, k=3, d=2, k_stride=2, d_stride=1)

        # Add 3D DenseNet blocks
        for block in range(self.total_blocks):
            with tf.variable_scope("Block_%d" % block):
                output = self._add_block(output, self.growth_rate,
                                         self.layers_per_block)
            # The last block exist without transition layer
            if block != self.total_blocks - 1:
                with tf.variable_scope("Transition_after_block_%d" % block):
                    output = self._transition_layer(output, pool_depth=2)

        # Fully connected layers
        with tf.variable_scope('Transition_to_classes'):
            self._logits = self._trainsition_layer_to_classes(output)

        # Prediction result
        self._prediction = tf.argmax(self._logits, 1)

        # Losses
        self._cross_entropy = tf.reduce_mean(
            tf.nn.sparse_softmax_cross_entropy_with_logits(
                logits=self._logits, labels=self.labels),
            name='Cross_entropy')
        self.l2_loss = tf.add_n(
            [tf.nn.l2_loss(var) for var in tf.trainable_variables()])
        self.total_loss = self._cross_entropy + self.l2_loss * self.weight_decay

        # Optimizer and training op
        self._train_op = tf.contrib.layers.optimize_loss(
            loss=self.total_loss,
            global_step=self.global_step,
            learning_rate=self.learning_rate,
            optimizer='Momentum')

    @property
    def logits(self):
        return self._logits

    @property
    def train_op(self):
        return self._train_op

    @property
    def losses(self):
        return self._cross_entropy

    @property
    def prediction(self):
        return self._prediction

    @property
    def accuracy(self):
        correct_prediction = tf.equal(tf.argmax(self._logits, 1), self.labels)
        return tf.metrics.mean(tf.cast(correct_prediction, tf.float32))

    @property
    def is_training(self):
        return self._is_training

    @is_training.setter
    def is_training(self, value):
        self._is_training = tf.convert_to_tensor(value)

    def _conv3d(self,
                inputs,
                out_features_count,
                kernel_size,
                strides=[1, 1, 1, 1, 1],
                padding='SAME'):
        input_features_count = int(inputs.get_shape()[-1])
        kernel = tf.get_variable(
            'kernel',
            shape=[
                kernel_size, kernel_size, kernel_size, input_features_count,
                out_features_count
            ],
            initializer=tf.random_normal_initializer())
        with tf.name_scope('3d_conv'):
            return tf.nn.conv3d(
                inputs, filter=kernel, strides=strides, padding=padding)

    def _pool(self,
              inputs,
              k,
              d=2,
              k_stride=None,
              d_stride=None,
              width_k=None,
              k_stride_width=None):
        if not width_k:
            width_k = k
        kernel_size = [1, d, k, width_k, 1]
        if not k_stride:
            k_stride = k
        if not k_stride_width:
            k_stride_width = k_stride
        if not d_stride:
            d_stride = d
        strides = [1, d_stride, k_stride, k_stride_width, 1]
        return tf.nn.max_pool3d(
            inputs, ksize=kernel_size, strides=strides, padding='SAME')

    def _add_block(self, inputs, growth_rate, layers_per_block):
        for layer in range(layers_per_block):
            with tf.variable_scope("layer_%d" % layer):
                return self._add_internal_layer(inputs, growth_rate)

    def _add_internal_layer(self, inputs, growth_rate):
        if not self.bc_mode:
            composite_out = self._composite_function(
                inputs, out_features_count=growth_rate, kernel_size=3)
        elif self.bc_mode:
            bottleneck_out = self._bottleneck(
                inputs, out_features_count=growth_rate)
            composite_out = self._composite_function(
                bottleneck_out, out_features_count=growth_rate, kernel_size=3)

        with tf.name_scope('concat'):
            return tf.concat(axis=4, values=(inputs, composite_out))

    def _composite_function(self, inputs, out_features_count, kernel_size):
        with tf.variable_scope('composite_function'):
            # Batch normalization
            output = self._batch_norm(inputs)
            # ReLU
            with tf.name_scope('ReLU'):
                output = tf.nn.relu(output)
            # Convolution
            output = self._conv3d(
                output,
                out_features_count=out_features_count,
                kernel_size=kernel_size)
            # Dropout
            output = self._dropout(output)
        return output

    def _bottleneck(self, inputs, out_features_count):
        with tf.variable_scope('bottleneck'):
            # Batch normalization
            output = self._batch_norm(inputs)
            # ReLU
            with tf.name_scope('ReLU'):
                output = tf.nn.relu(output)

            inter_features = out_features_count * 4
            output = self._conv3d(
                output,
                out_features_count=inter_features,
                kernel_size=1,
                padding='VALID')
            output = self._dropout(output)
        return output

    def _batch_norm(self, inputs):
        with tf.name_scope('batch_normalization'):
            output = tf.contrib.layers.batch_norm(
                inputs,
                scale=True,
                is_training=self._is_training,
                updates_collections=None)
        return output

    def _dropout(self, inputs):
        if self.keep_prob < 1:
            with tf.name_scope('dropout'):
                output = tf.cond(self._is_training,
                                 lambda: tf.nn.dropout(inputs, self.keep_prob),
                                 lambda: inputs)
        else:
            output = inputs
        return output

    def _transition_layer(self, inputs, pool_depth):
        out_features_count = int(int(inputs.get_shape()[-1]) * self.reduction)
        output = self._composite_function(
            inputs, out_features_count=out_features_count, kernel_size=1)
        with tf.name_scope('pooling'):
            output = self._pool(output, k=2, d=pool_depth)
        return output

    def _trainsition_layer_to_classes(self, inputs):
        # Batch normalization
        output = self._batch_norm(inputs)
        # ReLU
        with tf.name_scope('ReLU'):
            output = tf.nn.relu(output)
        # pooling
        last_pool_kernel_width = int(output.get_shape()[-2])
        last_pool_kernel_height = int(output.get_shape()[-3])
        last_sequence_length = int(output.get_shape()[1])
        with tf.name_scope('pooling'):
            output = self._pool(
                output,
                k=last_pool_kernel_height,
                d=last_sequence_length,
                width_k=last_pool_kernel_width,
                k_stride_width=last_pool_kernel_width)
        # Fully connected
        features_total = int(output.get_shape()[-1])
        output = tf.reshape(output, [-1, features_total])
        weight = tf.get_variable(
            'fc_w',
            shape=[features_total, self.num_classes],
            initializer=tf.contrib.layers.xavier_initializer())
        bias = tf.get_variable(
            'fc_bias',
            shape=[self.num_classes],
            initializer=tf.zeros_initializer())
        logits = tf.matmul(output, weight) + bias
        return logits

def model_fn(features, labels, mode, params):
    # Define the model
    model = DenseNet3D(
        video_clips=features['video_clips'], labels=labels, **params)

    # Get the prediction result
    if mode == tf.estimator.ModeKeys.PREDICT:
        model.is_training = False
        return _predict_result(model.logits)

    return tf.estimator.EstimatorSpec(
        mode=mode,
        loss=model.losses,
        train_op=model.train_op,
        eval_metric_ops={'eval_accuracy': model.accuracy})


def _predict_result(model):
    predictions = {'probabilities': model.prediction, 'logits': model.logits}
    return tf.estimator.EstimatorSpec(
        mode=tf.estimator.ModeKeys.PREDICT, predictions=predictions)


def serving_input_fn(params):
    inputs = {
        'video_clips':
        tf.placeholder(
            tf.float32,
            shape=[
                None, params['num_frames_per_clip'], params['height'],
                params['width'], params['channel']
            ])
    }
    return tf.estimator.export.build_raw_serving_input_receiver_fn(inputs)()


def train_input_fn(training_dir, params):
    directory = os.path.join(training_dir, 'train.tfrecord')
    return _build_tfrecord_dataset(directory, params['train_total_video_clip'],
                                   **params)


def eval_input_fn(evaluating_dir, params):
    directory = os.path.join(evaluating_dir, 'eval.tfrecord')
    return _build_tfrecord_dataset(directory, params['eval_total_video_clip'],
                                   **params)


def _build_tfrecord_dataset(directory, total_clip_num, batch_size, **params):
    '''
    Buffer the training dataset to TFRecordDataset with the following video shape
    [num_frames_per_clip, height, width, channel]
    ex: [16, 100, 120, 3]
    '''
    dataset = tf.data.TFRecordDataset(directory)
    dataset = dataset.shuffle(buffer_size=total_clip_num)
    dataset = dataset.map(
        map_func=
        lambda serialized_example: _parser(serialized_example, **params))
    dataset = dataset.repeat()
    iterator = dataset.batch(batch_size=batch_size).make_one_shot_iterator()
    clips, labels = iterator.get_next()
    return {'video_clips': clips}, labels


def _parser(serialized_example, num_frames_per_clip, **params):
    features = tf.parse_single_example(
        serialized_example,
        features={
            'clip/width': tf.FixedLenFeature([], tf.int64),
            'clip/height': tf.FixedLenFeature([], tf.int64),
            'clip/channel': tf.FixedLenFeature([], tf.int64),
            'clip/raw': tf.FixedLenFeature([num_frames_per_clip], tf.string),
            'clip/label': tf.FixedLenFeature([], tf.int64)
        })

    def mapping_func(image):
        return _decode_image(image, **params)

    clip = tf.map_fn(mapping_func, features['clip/raw'], dtype=tf.float32)
    return clip, features['clip/label']


def _decode_image(image, channel, width, height, **params):
    image = tf.image.decode_jpeg(image, channels=channel)
    # This set_shape step is necesary for the last trainsition_layer_to_classes layer in the model
    image.set_shape([height, width, channel])
    image = tf.cast(image, tf.float32)
    return image

"""This is the main class"""


MODEL_DIR = 'denseNet3d_result'
DATA_DIR = '/content'

HYPERPARAMETERS = {
    'num_classes': 6,  # The number of the classes that this dataset had
    'batch_size': 20,
    'initial_learning_rate': 0.1,
    'decay_step': 5000,
    'lr_decay_factor':
    0.1,  # Learning rate will decay by a factor for every decay_step
    'growth_rate': 12,  # Grows rate for every layer [12, 24, 40]
    'network_depth': 20,  # Depth of the whole network [20, 40, 250]
    'total_blocks': 3,  # Total blocks of layers stack
    'keep_prob': 0.9,  # Keep probability for dropout
    'weight_decay': 1e-4,  # Weight decay for L2 loss
    'model_type': 'DenseNet3D',
    'reduction': 0.5,  # Reduction rate at transition layer for the models
    'bc_mode': True,
    'num_frames_per_clip': 16,  # The length of the video clip
    'width': 120,
    'height': 100,
    'channel': 3,
    'train_total_video_clip': 5212,
    'eval_total_video_clip': 600
}

TFRUNCONFIG = tf.estimator.RunConfig(
    log_step_count_steps=1, save_summary_steps=1, model_dir=MODEL_DIR)

CLASSIFIER = tf.estimator.Estimator(
    model_fn=model_fn, params=HYPERPARAMETERS, config=TFRUNCONFIG)

CLASSIFIER.train(
    input_fn=lambda: train_input_fn(DATA_DIR, HYPERPARAMETERS),
    steps=1040)

CLASSIFIER.evaluate(
    input_fn=lambda: eval_input_fn(DATA_DIR, HYPERPARAMETERS),
    steps=30)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'denseNet3d_result', '_tf_random_seed': None, '_save_summary_steps': 1, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 1, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f8fa51ae940>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# Build 3D DenseNet-BC model with 3 blocks, 2 bottleneck layers and 2 composite layers each.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from denseNet3d_result/model.ckpt-3380
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3380 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:loss = 0.67856944, step = 3381
# INFO:tensorflow:global_step/sec: 0.0306116
# INFO:tensorflow:loss = 0.47400847, step = 3382 (32.670 sec)
# INFO:tensorflow:global_step/sec: 0.0305422
# INFO:tensorflow:loss = 0.27733836, step = 3383 (32.741 sec)
# INFO:tensorflow:global_step/sec: 0.0304637
# INFO:tensorflow:loss = 0.75973594, step = 3384 (32.833 sec)
# INFO:tensorflow:global_step/sec: 0.0317758
# INFO:tensorflow:loss = 0.4633417, step = 3385 (31.464 sec)
# INFO:tensorflow:global_step/sec: 0.0323956
# INFO:tensorflow:loss = 0.57947624, step = 3386 (30.872 sec)
# INFO:tensorflow:global_step/sec: 0.0319565
# INFO:tensorflow:loss = 0.5463113, step = 3387 (31.289 sec)
# INFO:tensorflow:global_step/sec: 0.0323742
# INFO:tensorflow:loss = 0.63530105, step = 3388 (30.888 sec)
# INFO:tensorflow:global_step/sec: 0.0321284
# INFO:tensorflow:loss = 0.5591167, step = 3389 (31.125 sec)
# INFO:tensorflow:global_step/sec: 0.0322916
# INFO:tensorflow:loss = 0.4279016, step = 3390 (30.968 sec)
# INFO:tensorflow:global_step/sec: 0.0319799
# INFO:tensorflow:loss = 0.7208994, step = 3391 (31.277 sec)
# INFO:tensorflow:global_step/sec: 0.0321752
# INFO:tensorflow:loss = 0.6898564, step = 3392 (31.075 sec)
# INFO:tensorflow:global_step/sec: 0.0315921
# INFO:tensorflow:loss = 0.61154157, step = 3393 (31.650 sec)
# INFO:tensorflow:global_step/sec: 0.0322321
# INFO:tensorflow:loss = 0.3119486, step = 3394 (31.025 sec)
# INFO:tensorflow:global_step/sec: 0.0325384
# INFO:tensorflow:loss = 0.58062285, step = 3395 (30.733 sec)
# INFO:tensorflow:global_step/sec: 0.032432
# INFO:tensorflow:loss = 0.76414573, step = 3396 (30.833 sec)
# INFO:tensorflow:global_step/sec: 0.0323542
# INFO:tensorflow:loss = 0.92163295, step = 3397 (30.916 sec)
# INFO:tensorflow:global_step/sec: 0.0323812
# INFO:tensorflow:loss = 0.99668694, step = 3398 (30.874 sec)
# INFO:tensorflow:global_step/sec: 0.0326258
# INFO:tensorflow:loss = 0.50116587, step = 3399 (30.650 sec)
# INFO:tensorflow:Saving checkpoints for 3400 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0323532
# INFO:tensorflow:loss = 0.897648, step = 3400 (30.909 sec)
# INFO:tensorflow:global_step/sec: 0.0324387
# INFO:tensorflow:loss = 0.8123642, step = 3401 (30.828 sec)
# INFO:tensorflow:global_step/sec: 0.0325956
# INFO:tensorflow:loss = 0.7689931, step = 3402 (30.685 sec)
# INFO:tensorflow:global_step/sec: 0.0324933
# INFO:tensorflow:loss = 0.3174019, step = 3403 (30.770 sec)
# INFO:tensorflow:global_step/sec: 0.0321944
# INFO:tensorflow:loss = 0.30785403, step = 3404 (31.061 sec)
# INFO:tensorflow:global_step/sec: 0.032417
# INFO:tensorflow:loss = 0.92508876, step = 3405 (30.848 sec)
# INFO:tensorflow:global_step/sec: 0.0326384
# INFO:tensorflow:loss = 0.5954895, step = 3406 (30.639 sec)
# INFO:tensorflow:global_step/sec: 0.0325668
# INFO:tensorflow:loss = 0.4434603, step = 3407 (30.706 sec)
# INFO:tensorflow:global_step/sec: 0.0326039
# INFO:tensorflow:loss = 0.6251403, step = 3408 (30.676 sec)
# INFO:tensorflow:global_step/sec: 0.0326016
# INFO:tensorflow:loss = 0.61797607, step = 3409 (30.674 sec)
# INFO:tensorflow:global_step/sec: 0.0325001
# INFO:tensorflow:loss = 0.6114713, step = 3410 (30.765 sec)
# INFO:tensorflow:global_step/sec: 0.0326002
# INFO:tensorflow:loss = 0.36313716, step = 3411 (30.675 sec)
# INFO:tensorflow:global_step/sec: 0.032556
# INFO:tensorflow:loss = 0.63081014, step = 3412 (30.716 sec)
# INFO:tensorflow:global_step/sec: 0.0325789
# INFO:tensorflow:loss = 0.43888125, step = 3413 (30.695 sec)
# INFO:tensorflow:global_step/sec: 0.0321475
# INFO:tensorflow:loss = 0.38665837, step = 3414 (31.109 sec)
# INFO:tensorflow:global_step/sec: 0.0324893
# INFO:tensorflow:loss = 0.48523515, step = 3415 (30.777 sec)
# INFO:tensorflow:global_step/sec: 0.0325463
# INFO:tensorflow:loss = 0.64167446, step = 3416 (30.725 sec)
# INFO:tensorflow:global_step/sec: 0.0325014
# INFO:tensorflow:loss = 0.5709964, step = 3417 (30.769 sec)
# INFO:tensorflow:global_step/sec: 0.0323979
# INFO:tensorflow:loss = 0.5464251, step = 3418 (30.869 sec)
# INFO:tensorflow:global_step/sec: 0.0320213
# INFO:tensorflow:loss = 1.1140013, step = 3419 (31.226 sec)
# INFO:tensorflow:Saving checkpoints for 3420 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.03183
# INFO:tensorflow:loss = 1.3057855, step = 3420 (31.416 sec)
# INFO:tensorflow:global_step/sec: 0.0321755
# INFO:tensorflow:loss = 0.27893132, step = 3421 (31.079 sec)
# INFO:tensorflow:global_step/sec: 0.0322582
# INFO:tensorflow:loss = 0.38865983, step = 3422 (31.002 sec)
# INFO:tensorflow:global_step/sec: 0.032124
# INFO:tensorflow:loss = 0.5404897, step = 3423 (31.127 sec)
# INFO:tensorflow:global_step/sec: 0.032003
# INFO:tensorflow:loss = 0.36898765, step = 3424 (31.247 sec)
# INFO:tensorflow:global_step/sec: 0.0323222
# INFO:tensorflow:loss = 0.51382977, step = 3425 (30.938 sec)
# INFO:tensorflow:global_step/sec: 0.032324
# INFO:tensorflow:loss = 0.68346155, step = 3426 (30.937 sec)
# INFO:tensorflow:global_step/sec: 0.032256
# INFO:tensorflow:loss = 0.8643082, step = 3427 (31.002 sec)
# INFO:tensorflow:global_step/sec: 0.032141
# INFO:tensorflow:loss = 0.8743863, step = 3428 (31.113 sec)
# INFO:tensorflow:global_step/sec: 0.0323669
# INFO:tensorflow:loss = 0.6211114, step = 3429 (30.896 sec)
# INFO:tensorflow:global_step/sec: 0.0325203
# INFO:tensorflow:loss = 0.44515926, step = 3430 (30.750 sec)
# INFO:tensorflow:global_step/sec: 0.0318676
# INFO:tensorflow:loss = 0.40956149, step = 3431 (31.380 sec)
# INFO:tensorflow:global_step/sec: 0.0322283
# INFO:tensorflow:loss = 0.89955187, step = 3432 (31.029 sec)
# INFO:tensorflow:global_step/sec: 0.0314258
# INFO:tensorflow:loss = 0.5207703, step = 3433 (31.821 sec)
# INFO:tensorflow:global_step/sec: 0.0309706
# INFO:tensorflow:loss = 0.45884776, step = 3434 (32.288 sec)
# INFO:tensorflow:global_step/sec: 0.031044
# INFO:tensorflow:loss = 0.8079175, step = 3435 (32.213 sec)
# INFO:tensorflow:global_step/sec: 0.0307099
# INFO:tensorflow:loss = 0.36120704, step = 3436 (32.562 sec)
# INFO:tensorflow:global_step/sec: 0.0313516
# INFO:tensorflow:loss = 0.91721666, step = 3437 (31.906 sec)
# INFO:tensorflow:global_step/sec: 0.0313777
# INFO:tensorflow:loss = 0.45883584, step = 3438 (31.863 sec)
# INFO:tensorflow:global_step/sec: 0.0302865
# INFO:tensorflow:loss = 0.7650826, step = 3439 (33.026 sec)
# INFO:tensorflow:Saving checkpoints for 3440 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0308698
# INFO:tensorflow:loss = 1.259003, step = 3440 (32.384 sec)
# INFO:tensorflow:global_step/sec: 0.030561
# INFO:tensorflow:loss = 0.60391533, step = 3441 (32.734 sec)
# INFO:tensorflow:global_step/sec: 0.0311893
# INFO:tensorflow:loss = 0.82896596, step = 3442 (32.050 sec)
# INFO:tensorflow:global_step/sec: 0.0308282
# INFO:tensorflow:loss = 1.1100371, step = 3443 (32.438 sec)
# INFO:tensorflow:global_step/sec: 0.0310777
# INFO:tensorflow:loss = 0.41699848, step = 3444 (32.177 sec)
# INFO:tensorflow:global_step/sec: 0.0315101
# INFO:tensorflow:loss = 0.586351, step = 3445 (31.744 sec)
# INFO:tensorflow:global_step/sec: 0.0313918
# INFO:tensorflow:loss = 0.8181815, step = 3446 (31.848 sec)
# INFO:tensorflow:global_step/sec: 0.0308972
# INFO:tensorflow:loss = 0.44638476, step = 3447 (32.366 sec)
# INFO:tensorflow:global_step/sec: 0.0306855
# INFO:tensorflow:loss = 0.62912273, step = 3448 (32.588 sec)
# INFO:tensorflow:global_step/sec: 0.0308809
# INFO:tensorflow:loss = 0.64678395, step = 3449 (32.383 sec)
# INFO:tensorflow:global_step/sec: 0.0305968
# INFO:tensorflow:loss = 1.3198973, step = 3450 (32.682 sec)
# INFO:tensorflow:global_step/sec: 0.0309867
# INFO:tensorflow:loss = 0.5747903, step = 3451 (32.272 sec)
# INFO:tensorflow:global_step/sec: 0.0312775
# INFO:tensorflow:loss = 0.60624075, step = 3452 (31.972 sec)
# INFO:tensorflow:global_step/sec: 0.0313406
# INFO:tensorflow:loss = 0.5517231, step = 3453 (31.907 sec)
# INFO:tensorflow:global_step/sec: 0.0313509
# INFO:tensorflow:loss = 0.84637517, step = 3454 (31.897 sec)
# INFO:tensorflow:global_step/sec: 0.0309093
# INFO:tensorflow:loss = 1.038768, step = 3455 (32.353 sec)
# INFO:tensorflow:global_step/sec: 0.0314296
# INFO:tensorflow:loss = 0.91927063, step = 3456 (31.816 sec)
# INFO:tensorflow:global_step/sec: 0.0304735
# INFO:tensorflow:loss = 0.77928054, step = 3457 (32.823 sec)
# INFO:tensorflow:global_step/sec: 0.0311686
# INFO:tensorflow:loss = 0.628751, step = 3458 (32.076 sec)
# INFO:tensorflow:Saving checkpoints for 3459 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0309002
# INFO:tensorflow:loss = 1.3135179, step = 3459 (32.362 sec)
# INFO:tensorflow:global_step/sec: 0.0308729
# INFO:tensorflow:loss = 1.3010347, step = 3460 (32.391 sec)
# INFO:tensorflow:global_step/sec: 0.0314298
# INFO:tensorflow:loss = 0.6672269, step = 3461 (31.816 sec)
# INFO:tensorflow:global_step/sec: 0.0311533
# INFO:tensorflow:loss = 0.8093004, step = 3462 (32.100 sec)
# INFO:tensorflow:global_step/sec: 0.0312977
# INFO:tensorflow:loss = 1.0067047, step = 3463 (31.952 sec)
# INFO:tensorflow:global_step/sec: 0.0318621
# INFO:tensorflow:loss = 1.088909, step = 3464 (31.384 sec)
# INFO:tensorflow:global_step/sec: 0.0314444
# INFO:tensorflow:loss = 0.62213576, step = 3465 (31.802 sec)
# INFO:tensorflow:global_step/sec: 0.0314999
# INFO:tensorflow:loss = 0.8407904, step = 3466 (31.752 sec)
# INFO:tensorflow:global_step/sec: 0.0317415
# INFO:tensorflow:loss = 0.9552437, step = 3467 (31.499 sec)
# INFO:tensorflow:global_step/sec: 0.0314549
# INFO:tensorflow:loss = 0.7417145, step = 3468 (31.799 sec)
# INFO:tensorflow:global_step/sec: 0.0316144
# INFO:tensorflow:loss = 0.79652226, step = 3469 (31.627 sec)
# INFO:tensorflow:global_step/sec: 0.0312187
# INFO:tensorflow:loss = 0.57338536, step = 3470 (32.029 sec)
# INFO:tensorflow:global_step/sec: 0.0314578
# INFO:tensorflow:loss = 0.79634356, step = 3471 (31.788 sec)
# INFO:tensorflow:global_step/sec: 0.0314175
# INFO:tensorflow:loss = 0.6826474, step = 3472 (31.830 sec)
# INFO:tensorflow:global_step/sec: 0.0316909
# INFO:tensorflow:loss = 1.145408, step = 3473 (31.555 sec)
# INFO:tensorflow:global_step/sec: 0.0318661
# INFO:tensorflow:loss = 0.36467046, step = 3474 (31.381 sec)
# INFO:tensorflow:global_step/sec: 0.0320216
# INFO:tensorflow:loss = 0.7512229, step = 3475 (31.232 sec)
# INFO:tensorflow:global_step/sec: 0.0312086
# INFO:tensorflow:loss = 0.9718758, step = 3476 (32.043 sec)
# INFO:tensorflow:global_step/sec: 0.0315287
# INFO:tensorflow:loss = 0.6381954, step = 3477 (31.713 sec)
# INFO:tensorflow:Saving checkpoints for 3478 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.031581
# INFO:tensorflow:loss = 0.78856784, step = 3478 (31.668 sec)
# INFO:tensorflow:global_step/sec: 0.0311867
# INFO:tensorflow:loss = 0.56844217, step = 3479 (32.062 sec)
# INFO:tensorflow:global_step/sec: 0.0305489
# INFO:tensorflow:loss = 0.7361517, step = 3480 (32.742 sec)
# INFO:tensorflow:global_step/sec: 0.0314489
# INFO:tensorflow:loss = 0.72977144, step = 3481 (31.790 sec)
# INFO:tensorflow:global_step/sec: 0.0314494
# INFO:tensorflow:loss = 0.39710334, step = 3482 (31.797 sec)
# INFO:tensorflow:global_step/sec: 0.0317042
# INFO:tensorflow:loss = 0.63846874, step = 3483 (31.542 sec)
# INFO:tensorflow:global_step/sec: 0.0320675
# INFO:tensorflow:loss = 0.8223565, step = 3484 (31.184 sec)
# INFO:tensorflow:global_step/sec: 0.0321048
# INFO:tensorflow:loss = 0.71495, step = 3485 (31.149 sec)
# INFO:tensorflow:global_step/sec: 0.0320854
# INFO:tensorflow:loss = 0.9814518, step = 3486 (31.166 sec)
# INFO:tensorflow:global_step/sec: 0.0321345
# INFO:tensorflow:loss = 0.87662685, step = 3487 (31.119 sec)
# INFO:tensorflow:global_step/sec: 0.0321661
# INFO:tensorflow:loss = 0.6744455, step = 3488 (31.094 sec)
# INFO:tensorflow:global_step/sec: 0.0319769
# INFO:tensorflow:loss = 0.8757137, step = 3489 (31.268 sec)
# INFO:tensorflow:global_step/sec: 0.0320866
# INFO:tensorflow:loss = 0.7453633, step = 3490 (31.166 sec)
# INFO:tensorflow:global_step/sec: 0.0321834
# INFO:tensorflow:loss = 0.54346293, step = 3491 (31.071 sec)
# INFO:tensorflow:global_step/sec: 0.0322027
# INFO:tensorflow:loss = 0.9207959, step = 3492 (31.054 sec)
# INFO:tensorflow:global_step/sec: 0.0321856
# INFO:tensorflow:loss = 0.36776072, step = 3493 (31.069 sec)
# INFO:tensorflow:global_step/sec: 0.0320336
# INFO:tensorflow:loss = 0.5567379, step = 3494 (31.222 sec)
# INFO:tensorflow:global_step/sec: 0.0320312
# INFO:tensorflow:loss = 0.6356133, step = 3495 (31.215 sec)
# INFO:tensorflow:global_step/sec: 0.0319076
# INFO:tensorflow:loss = 1.1036495, step = 3496 (31.340 sec)
# INFO:tensorflow:global_step/sec: 0.0316704
# INFO:tensorflow:loss = 0.79221326, step = 3497 (31.576 sec)
# INFO:tensorflow:Saving checkpoints for 3498 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0310829
# INFO:tensorflow:loss = 1.050364, step = 3498 (32.172 sec)
# INFO:tensorflow:global_step/sec: 0.0309733
# INFO:tensorflow:loss = 0.9351885, step = 3499 (32.286 sec)
# INFO:tensorflow:global_step/sec: 0.031392
# INFO:tensorflow:loss = 0.9145899, step = 3500 (31.863 sec)
# INFO:tensorflow:global_step/sec: 0.0311008
# INFO:tensorflow:loss = 0.4498251, step = 3501 (32.145 sec)
# INFO:tensorflow:global_step/sec: 0.0312165
# INFO:tensorflow:loss = 1.2761394, step = 3502 (32.043 sec)
# INFO:tensorflow:global_step/sec: 0.0313508
# INFO:tensorflow:loss = 0.81010896, step = 3503 (31.889 sec)
# INFO:tensorflow:global_step/sec: 0.0308612
# INFO:tensorflow:loss = 1.0368334, step = 3504 (32.403 sec)
# INFO:tensorflow:global_step/sec: 0.0308772
# INFO:tensorflow:loss = 1.0362536, step = 3505 (32.386 sec)
# INFO:tensorflow:global_step/sec: 0.0312336
# INFO:tensorflow:loss = 0.56176025, step = 3506 (32.017 sec)
# INFO:tensorflow:global_step/sec: 0.0312839
# INFO:tensorflow:loss = 0.9112029, step = 3507 (31.967 sec)
# INFO:tensorflow:global_step/sec: 0.030994
# INFO:tensorflow:loss = 0.7714798, step = 3508 (32.266 sec)
# INFO:tensorflow:global_step/sec: 0.0303612
# INFO:tensorflow:loss = 1.2156106, step = 3509 (32.933 sec)
# INFO:tensorflow:global_step/sec: 0.0308632
# INFO:tensorflow:loss = 0.76899195, step = 3510 (32.404 sec)
# INFO:tensorflow:global_step/sec: 0.0305884
# INFO:tensorflow:loss = 0.5470878, step = 3511 (32.691 sec)
# INFO:tensorflow:global_step/sec: 0.0307484
# INFO:tensorflow:loss = 0.36667305, step = 3512 (32.521 sec)
# INFO:tensorflow:global_step/sec: 0.0308096
# INFO:tensorflow:loss = 0.89501303, step = 3513 (32.457 sec)
# INFO:tensorflow:global_step/sec: 0.0307629
# INFO:tensorflow:loss = 0.57591283, step = 3514 (32.507 sec)
# INFO:tensorflow:global_step/sec: 0.0304602
# INFO:tensorflow:loss = 0.47034988, step = 3515 (32.831 sec)
# INFO:tensorflow:global_step/sec: 0.0306875
# INFO:tensorflow:loss = 0.6344202, step = 3516 (32.585 sec)
# INFO:tensorflow:Saving checkpoints for 3517 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0305529
# INFO:tensorflow:loss = 0.8361381, step = 3517 (32.730 sec)
# INFO:tensorflow:global_step/sec: 0.031188
# INFO:tensorflow:loss = 0.5372256, step = 3518 (32.068 sec)
# INFO:tensorflow:global_step/sec: 0.0297807
# INFO:tensorflow:loss = 0.8108627, step = 3519 (33.575 sec)
# INFO:tensorflow:global_step/sec: 0.0310531
# INFO:tensorflow:loss = 0.5150351, step = 3520 (32.203 sec)
# INFO:tensorflow:global_step/sec: 0.0307354
# INFO:tensorflow:loss = 0.47809666, step = 3521 (32.536 sec)
# INFO:tensorflow:global_step/sec: 0.0309478
# INFO:tensorflow:loss = 0.7219486, step = 3522 (32.318 sec)
# INFO:tensorflow:global_step/sec: 0.0309429
# INFO:tensorflow:loss = 0.5584755, step = 3523 (32.317 sec)
# INFO:tensorflow:global_step/sec: 0.0304683
# INFO:tensorflow:loss = 0.26139927, step = 3524 (32.823 sec)
# INFO:tensorflow:global_step/sec: 0.0309955
# INFO:tensorflow:loss = 0.6249545, step = 3525 (32.255 sec)
# INFO:tensorflow:global_step/sec: 0.0312893
# INFO:tensorflow:loss = 1.145716, step = 3526 (31.959 sec)
# INFO:tensorflow:global_step/sec: 0.0312209
# INFO:tensorflow:loss = 0.90774506, step = 3527 (32.030 sec)
# INFO:tensorflow:global_step/sec: 0.0310073
# INFO:tensorflow:loss = 0.62815607, step = 3528 (32.251 sec)
# INFO:tensorflow:global_step/sec: 0.0310348
# INFO:tensorflow:loss = 0.7654065, step = 3529 (32.222 sec)
# INFO:tensorflow:global_step/sec: 0.0313241
# INFO:tensorflow:loss = 0.95827407, step = 3530 (31.924 sec)
# INFO:tensorflow:global_step/sec: 0.0311984
# INFO:tensorflow:loss = 0.70800173, step = 3531 (32.053 sec)
# INFO:tensorflow:global_step/sec: 0.0307167
# INFO:tensorflow:loss = 0.7407805, step = 3532 (32.555 sec)
# INFO:tensorflow:global_step/sec: 0.0314668
# INFO:tensorflow:loss = 0.9102044, step = 3533 (31.780 sec)
# INFO:tensorflow:global_step/sec: 0.0314914
# INFO:tensorflow:loss = 0.32240883, step = 3534 (31.754 sec)
# INFO:tensorflow:global_step/sec: 0.031003
# INFO:tensorflow:loss = 0.780656, step = 3535 (32.263 sec)
# INFO:tensorflow:Saving checkpoints for 3536 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0307063
# INFO:tensorflow:loss = 0.9013427, step = 3536 (32.558 sec)
# INFO:tensorflow:global_step/sec: 0.0308588
# INFO:tensorflow:loss = 0.5722952, step = 3537 (32.406 sec)
# INFO:tensorflow:global_step/sec: 0.0315991
# INFO:tensorflow:loss = 0.37725905, step = 3538 (31.647 sec)
# INFO:tensorflow:global_step/sec: 0.0316123
# INFO:tensorflow:loss = 0.8408203, step = 3539 (31.634 sec)
# INFO:tensorflow:global_step/sec: 0.0319513
# INFO:tensorflow:loss = 0.7577218, step = 3540 (31.297 sec)
# INFO:tensorflow:global_step/sec: 0.0320194
# INFO:tensorflow:loss = 0.65026915, step = 3541 (31.236 sec)
# INFO:tensorflow:global_step/sec: 0.0320485
# INFO:tensorflow:loss = 0.66272277, step = 3542 (31.198 sec)
# INFO:tensorflow:global_step/sec: 0.031834
# INFO:tensorflow:loss = 0.7442191, step = 3543 (31.414 sec)
# INFO:tensorflow:global_step/sec: 0.0321008
# INFO:tensorflow:loss = 0.8910945, step = 3544 (31.151 sec)
# INFO:tensorflow:global_step/sec: 0.0320654
# INFO:tensorflow:loss = 0.27798355, step = 3545 (31.190 sec)
# INFO:tensorflow:global_step/sec: 0.0320467
# INFO:tensorflow:loss = 0.50675464, step = 3546 (31.202 sec)
# INFO:tensorflow:global_step/sec: 0.0319605
# INFO:tensorflow:loss = 0.63543206, step = 3547 (31.288 sec)
# INFO:tensorflow:global_step/sec: 0.0316712
# INFO:tensorflow:loss = 0.44586855, step = 3548 (31.575 sec)
# INFO:tensorflow:global_step/sec: 0.0320726
# INFO:tensorflow:loss = 0.50672805, step = 3549 (31.179 sec)
# INFO:tensorflow:global_step/sec: 0.03194
# INFO:tensorflow:loss = 0.3363673, step = 3550 (31.318 sec)
# INFO:tensorflow:global_step/sec: 0.0319967
# INFO:tensorflow:loss = 0.81366646, step = 3551 (31.245 sec)
# INFO:tensorflow:global_step/sec: 0.0320905
# INFO:tensorflow:loss = 0.47605252, step = 3552 (31.162 sec)
# INFO:tensorflow:global_step/sec: 0.0319373
# INFO:tensorflow:loss = 0.47947353, step = 3553 (31.314 sec)
# INFO:tensorflow:global_step/sec: 0.032045
# INFO:tensorflow:loss = 0.5110114, step = 3554 (31.207 sec)
# INFO:tensorflow:global_step/sec: 0.0320384
# INFO:tensorflow:loss = 1.0845199, step = 3555 (31.215 sec)
# INFO:tensorflow:Saving checkpoints for 3556 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0317888
# INFO:tensorflow:loss = 0.7683482, step = 3556 (31.451 sec)
# INFO:tensorflow:global_step/sec: 0.0320036
# INFO:tensorflow:loss = 0.5343479, step = 3557 (31.251 sec)
# INFO:tensorflow:global_step/sec: 0.0318123
# INFO:tensorflow:loss = 0.59606344, step = 3558 (31.434 sec)
# INFO:tensorflow:global_step/sec: 0.0320871
# INFO:tensorflow:loss = 1.0033157, step = 3559 (31.161 sec)
# INFO:tensorflow:global_step/sec: 0.032075
# INFO:tensorflow:loss = 0.45913053, step = 3560 (31.177 sec)
# INFO:tensorflow:global_step/sec: 0.0322166
# INFO:tensorflow:loss = 0.6339844, step = 3561 (31.047 sec)
# INFO:tensorflow:global_step/sec: 0.0320022
# INFO:tensorflow:loss = 1.1120832, step = 3562 (31.241 sec)
# INFO:tensorflow:global_step/sec: 0.031977
# INFO:tensorflow:loss = 0.9679438, step = 3563 (31.273 sec)
# INFO:tensorflow:global_step/sec: 0.0320651
# INFO:tensorflow:loss = 0.7363648, step = 3564 (31.187 sec)
# INFO:tensorflow:global_step/sec: 0.0321163
# INFO:tensorflow:loss = 0.8082048, step = 3565 (31.137 sec)
# INFO:tensorflow:global_step/sec: 0.0321921
# INFO:tensorflow:loss = 0.6960536, step = 3566 (31.063 sec)
# INFO:tensorflow:global_step/sec: 0.0319857
# INFO:tensorflow:loss = 0.5985259, step = 3567 (31.271 sec)
# INFO:tensorflow:global_step/sec: 0.0317094
# INFO:tensorflow:loss = 0.3804973, step = 3568 (31.530 sec)
# INFO:tensorflow:global_step/sec: 0.0320711
# INFO:tensorflow:loss = 0.3558546, step = 3569 (31.181 sec)
# INFO:tensorflow:global_step/sec: 0.0319767
# INFO:tensorflow:loss = 0.50530875, step = 3570 (31.272 sec)
# INFO:tensorflow:global_step/sec: 0.0320367
# INFO:tensorflow:loss = 1.0286531, step = 3571 (31.215 sec)
# INFO:tensorflow:global_step/sec: 0.0320849
# INFO:tensorflow:loss = 0.2953993, step = 3572 (31.167 sec)
# INFO:tensorflow:global_step/sec: 0.0319733
# INFO:tensorflow:loss = 0.6437572, step = 3573 (31.283 sec)
# INFO:tensorflow:global_step/sec: 0.0319289
# INFO:tensorflow:loss = 0.71751654, step = 3574 (31.313 sec)
# INFO:tensorflow:global_step/sec: 0.0320233
# INFO:tensorflow:loss = 0.99906665, step = 3575 (31.227 sec)
# INFO:tensorflow:Saving checkpoints for 3576 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0317047
# INFO:tensorflow:loss = 0.3709309, step = 3576 (31.541 sec)
# INFO:tensorflow:global_step/sec: 0.0320225
# INFO:tensorflow:loss = 0.88099205, step = 3577 (31.229 sec)
# INFO:tensorflow:global_step/sec: 0.0314689
# INFO:tensorflow:loss = 0.71584725, step = 3578 (31.777 sec)
# INFO:tensorflow:global_step/sec: 0.0320693
# INFO:tensorflow:loss = 0.6827365, step = 3579 (31.185 sec)
# INFO:tensorflow:global_step/sec: 0.0319599
# INFO:tensorflow:loss = 0.76584786, step = 3580 (31.286 sec)
# INFO:tensorflow:global_step/sec: 0.0317521
# INFO:tensorflow:loss = 1.0611197, step = 3581 (31.495 sec)
# INFO:tensorflow:global_step/sec: 0.0317746
# INFO:tensorflow:loss = 0.5818853, step = 3582 (31.471 sec)
# INFO:tensorflow:global_step/sec: 0.0317862
# INFO:tensorflow:loss = 0.6630506, step = 3583 (31.460 sec)
# INFO:tensorflow:global_step/sec: 0.0320714
# INFO:tensorflow:loss = 0.6451945, step = 3584 (31.180 sec)
# INFO:tensorflow:global_step/sec: 0.0319691
# INFO:tensorflow:loss = 0.897608, step = 3585 (31.289 sec)
# INFO:tensorflow:global_step/sec: 0.0319961
# INFO:tensorflow:loss = 0.5152453, step = 3586 (31.254 sec)
# INFO:tensorflow:global_step/sec: 0.0319897
# INFO:tensorflow:loss = 0.44546396, step = 3587 (31.252 sec)
# INFO:tensorflow:global_step/sec: 0.0316254
# INFO:tensorflow:loss = 0.57405996, step = 3588 (31.620 sec)
# INFO:tensorflow:global_step/sec: 0.0319557
# INFO:tensorflow:loss = 0.3837556, step = 3589 (31.299 sec)
# INFO:tensorflow:global_step/sec: 0.0320038
# INFO:tensorflow:loss = 0.41429463, step = 3590 (31.242 sec)
# INFO:tensorflow:global_step/sec: 0.0318448
# INFO:tensorflow:loss = 0.5835963, step = 3591 (31.402 sec)
# INFO:tensorflow:global_step/sec: 0.0318197
# INFO:tensorflow:loss = 0.6999487, step = 3592 (31.427 sec)
# INFO:tensorflow:global_step/sec: 0.0318204
# INFO:tensorflow:loss = 0.7437496, step = 3593 (31.428 sec)
# INFO:tensorflow:global_step/sec: 0.0320072
# INFO:tensorflow:loss = 0.63173616, step = 3594 (31.242 sec)
# INFO:tensorflow:global_step/sec: 0.0320388
# INFO:tensorflow:loss = 0.56063586, step = 3595 (31.212 sec)
# INFO:tensorflow:Saving checkpoints for 3596 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.031599
# INFO:tensorflow:loss = 0.64245003, step = 3596 (31.646 sec)
# INFO:tensorflow:global_step/sec: 0.032103
# INFO:tensorflow:loss = 0.7694125, step = 3597 (31.151 sec)
# INFO:tensorflow:global_step/sec: 0.031874
# INFO:tensorflow:loss = 0.6555504, step = 3598 (31.374 sec)
# INFO:tensorflow:global_step/sec: 0.0321984
# INFO:tensorflow:loss = 1.243254, step = 3599 (31.056 sec)
# INFO:tensorflow:global_step/sec: 0.0321161
# INFO:tensorflow:loss = 0.6989605, step = 3600 (31.137 sec)
# INFO:tensorflow:global_step/sec: 0.031902
# INFO:tensorflow:loss = 0.8666455, step = 3601 (31.345 sec)
# INFO:tensorflow:global_step/sec: 0.0317794
# INFO:tensorflow:loss = 0.6507329, step = 3602 (31.467 sec)
# INFO:tensorflow:global_step/sec: 0.0320435
# INFO:tensorflow:loss = 0.48426524, step = 3603 (31.212 sec)
# INFO:tensorflow:global_step/sec: 0.032183
# INFO:tensorflow:loss = 0.6166556, step = 3604 (31.068 sec)
# INFO:tensorflow:global_step/sec: 0.0322021
# INFO:tensorflow:loss = 0.5752607, step = 3605 (31.054 sec)
# INFO:tensorflow:global_step/sec: 0.032237
# INFO:tensorflow:loss = 0.67354804, step = 3606 (31.021 sec)
# INFO:tensorflow:global_step/sec: 0.032114
# INFO:tensorflow:loss = 0.92054385, step = 3607 (31.139 sec)
# INFO:tensorflow:global_step/sec: 0.0319333
# INFO:tensorflow:loss = 0.62830025, step = 3608 (31.315 sec)
# INFO:tensorflow:global_step/sec: 0.0321699
# INFO:tensorflow:loss = 0.8889324, step = 3609 (31.085 sec)
# INFO:tensorflow:global_step/sec: 0.0322223
# INFO:tensorflow:loss = 1.1632856, step = 3610 (31.041 sec)
# INFO:tensorflow:global_step/sec: 0.0322637
# INFO:tensorflow:loss = 0.59686065, step = 3611 (30.988 sec)
# INFO:tensorflow:global_step/sec: 0.0319806
# INFO:tensorflow:loss = 0.9257928, step = 3612 (31.269 sec)
# INFO:tensorflow:global_step/sec: 0.0320973
# INFO:tensorflow:loss = 0.53627443, step = 3613 (31.155 sec)
# INFO:tensorflow:global_step/sec: 0.032251
# INFO:tensorflow:loss = 0.4271676, step = 3614 (31.007 sec)
# INFO:tensorflow:global_step/sec: 0.0322819
# INFO:tensorflow:loss = 0.5730299, step = 3615 (30.981 sec)
# INFO:tensorflow:Saving checkpoints for 3616 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0319324
# INFO:tensorflow:loss = 0.7991674, step = 3616 (31.312 sec)
# INFO:tensorflow:global_step/sec: 0.0322911
# INFO:tensorflow:loss = 0.5512503, step = 3617 (30.969 sec)
# INFO:tensorflow:global_step/sec: 0.0319538
# INFO:tensorflow:loss = 0.97124255, step = 3618 (31.303 sec)
# INFO:tensorflow:global_step/sec: 0.0322203
# INFO:tensorflow:loss = 0.8145935, step = 3619 (31.036 sec)
# INFO:tensorflow:global_step/sec: 0.0322126
# INFO:tensorflow:loss = 0.6338124, step = 3620 (31.036 sec)
# INFO:tensorflow:global_step/sec: 0.0322362
# INFO:tensorflow:loss = 1.732929, step = 3621 (31.021 sec)
# INFO:tensorflow:global_step/sec: 0.0321553
# INFO:tensorflow:loss = 1.1595027, step = 3622 (31.099 sec)
# INFO:tensorflow:global_step/sec: 0.0322163
# INFO:tensorflow:loss = 0.60119957, step = 3623 (31.040 sec)
# INFO:tensorflow:global_step/sec: 0.0322443
# INFO:tensorflow:loss = 0.9248654, step = 3624 (31.013 sec)
# INFO:tensorflow:global_step/sec: 0.0321768
# INFO:tensorflow:loss = 0.51685363, step = 3625 (31.078 sec)
# INFO:tensorflow:global_step/sec: 0.0322915
# INFO:tensorflow:loss = 0.8006902, step = 3626 (30.968 sec)
# INFO:tensorflow:global_step/sec: 0.0322776
# INFO:tensorflow:loss = 0.9791029, step = 3627 (30.982 sec)
# INFO:tensorflow:global_step/sec: 0.0318791
# INFO:tensorflow:loss = 0.56764185, step = 3628 (31.368 sec)
# INFO:tensorflow:global_step/sec: 0.0323159
# INFO:tensorflow:loss = 0.5028039, step = 3629 (30.945 sec)
# INFO:tensorflow:global_step/sec: 0.0322761
# INFO:tensorflow:loss = 0.861076, step = 3630 (30.986 sec)
# INFO:tensorflow:global_step/sec: 0.0321648
# INFO:tensorflow:loss = 0.50680286, step = 3631 (31.087 sec)
# INFO:tensorflow:global_step/sec: 0.0320492
# INFO:tensorflow:loss = 0.52138376, step = 3632 (31.201 sec)
# INFO:tensorflow:global_step/sec: 0.0322738
# INFO:tensorflow:loss = 0.71990895, step = 3633 (30.993 sec)
# INFO:tensorflow:global_step/sec: 0.032285
# INFO:tensorflow:loss = 0.6460426, step = 3634 (30.967 sec)
# INFO:tensorflow:global_step/sec: 0.0322813
# INFO:tensorflow:loss = 0.498146, step = 3635 (30.977 sec)
# INFO:tensorflow:Saving checkpoints for 3636 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0319875
# INFO:tensorflow:loss = 1.1236109, step = 3636 (31.261 sec)
# INFO:tensorflow:global_step/sec: 0.0323064
# INFO:tensorflow:loss = 0.82780266, step = 3637 (30.954 sec)
# INFO:tensorflow:global_step/sec: 0.0319431
# INFO:tensorflow:loss = 0.48429412, step = 3638 (31.306 sec)
# INFO:tensorflow:global_step/sec: 0.0321982
# INFO:tensorflow:loss = 1.0041965, step = 3639 (31.058 sec)
# INFO:tensorflow:global_step/sec: 0.0322847
# INFO:tensorflow:loss = 0.94811773, step = 3640 (30.977 sec)
# INFO:tensorflow:global_step/sec: 0.0315907
# INFO:tensorflow:loss = 0.7317871, step = 3641 (31.652 sec)
# INFO:tensorflow:global_step/sec: 0.0319173
# INFO:tensorflow:loss = 0.6491498, step = 3642 (31.330 sec)
# INFO:tensorflow:global_step/sec: 0.032067
# INFO:tensorflow:loss = 0.67168176, step = 3643 (31.185 sec)
# INFO:tensorflow:global_step/sec: 0.032098
# INFO:tensorflow:loss = 0.3326951, step = 3644 (31.161 sec)
# INFO:tensorflow:global_step/sec: 0.0321425
# INFO:tensorflow:loss = 0.54864156, step = 3645 (31.105 sec)
# INFO:tensorflow:global_step/sec: 0.0321571
# INFO:tensorflow:loss = 0.88919365, step = 3646 (31.097 sec)
# INFO:tensorflow:global_step/sec: 0.0321562
# INFO:tensorflow:loss = 0.752659, step = 3647 (31.099 sec)
# INFO:tensorflow:global_step/sec: 0.031837
# INFO:tensorflow:loss = 0.45409697, step = 3648 (31.410 sec)
# INFO:tensorflow:global_step/sec: 0.0322038
# INFO:tensorflow:loss = 1.0445982, step = 3649 (31.052 sec)
# INFO:tensorflow:global_step/sec: 0.0320974
# INFO:tensorflow:loss = 0.66945136, step = 3650 (31.157 sec)
# INFO:tensorflow:global_step/sec: 0.0319134
# INFO:tensorflow:loss = 0.91729087, step = 3651 (31.333 sec)
# INFO:tensorflow:global_step/sec: 0.0320935
# INFO:tensorflow:loss = 0.6534312, step = 3652 (31.159 sec)
# INFO:tensorflow:global_step/sec: 0.0320849
# INFO:tensorflow:loss = 0.3979621, step = 3653 (31.168 sec)
# INFO:tensorflow:global_step/sec: 0.0319541
# INFO:tensorflow:loss = 0.57620215, step = 3654 (31.295 sec)
# INFO:tensorflow:global_step/sec: 0.0321868
# INFO:tensorflow:loss = 0.42009935, step = 3655 (31.069 sec)
# INFO:tensorflow:Saving checkpoints for 3656 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0319468
# INFO:tensorflow:loss = 0.53045833, step = 3656 (31.305 sec)
# INFO:tensorflow:global_step/sec: 0.0322477
# INFO:tensorflow:loss = 0.6602399, step = 3657 (31.007 sec)
# INFO:tensorflow:global_step/sec: 0.0318814
# INFO:tensorflow:loss = 0.9674305, step = 3658 (31.366 sec)
# INFO:tensorflow:global_step/sec: 0.0321782
# INFO:tensorflow:loss = 0.444868, step = 3659 (31.080 sec)
# INFO:tensorflow:global_step/sec: 0.0322075
# INFO:tensorflow:loss = 0.41861683, step = 3660 (31.045 sec)
# INFO:tensorflow:global_step/sec: 0.0321192
# INFO:tensorflow:loss = 0.63597125, step = 3661 (31.134 sec)
# INFO:tensorflow:global_step/sec: 0.0322031
# INFO:tensorflow:loss = 1.0747668, step = 3662 (31.062 sec)
# INFO:tensorflow:global_step/sec: 0.0321429
# INFO:tensorflow:loss = 0.3612563, step = 3663 (31.103 sec)
# INFO:tensorflow:global_step/sec: 0.0321772
# INFO:tensorflow:loss = 0.6199248, step = 3664 (31.078 sec)
# INFO:tensorflow:global_step/sec: 0.0322488
# INFO:tensorflow:loss = 0.7801407, step = 3665 (31.009 sec)
# INFO:tensorflow:global_step/sec: 0.0321733
# INFO:tensorflow:loss = 0.6521549, step = 3666 (31.082 sec)
# INFO:tensorflow:global_step/sec: 0.0322605
# INFO:tensorflow:loss = 0.67591685, step = 3667 (30.997 sec)
# INFO:tensorflow:global_step/sec: 0.0319455
# INFO:tensorflow:loss = 1.0790141, step = 3668 (31.309 sec)
# INFO:tensorflow:global_step/sec: 0.0322177
# INFO:tensorflow:loss = 0.90768546, step = 3669 (31.040 sec)
# INFO:tensorflow:global_step/sec: 0.0320059
# INFO:tensorflow:loss = 0.39368576, step = 3670 (31.244 sec)
# INFO:tensorflow:global_step/sec: 0.0319163
# INFO:tensorflow:loss = 0.43245816, step = 3671 (31.326 sec)
# INFO:tensorflow:global_step/sec: 0.0320978
# INFO:tensorflow:loss = 1.0233624, step = 3672 (31.155 sec)
# INFO:tensorflow:global_step/sec: 0.032071
# INFO:tensorflow:loss = 0.5115918, step = 3673 (31.180 sec)
# INFO:tensorflow:global_step/sec: 0.0319356
# INFO:tensorflow:loss = 0.81759584, step = 3674 (31.321 sec)
# INFO:tensorflow:global_step/sec: 0.0321111
# INFO:tensorflow:loss = 0.7894257, step = 3675 (31.135 sec)
# INFO:tensorflow:Saving checkpoints for 3676 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0318329
# INFO:tensorflow:loss = 0.43467966, step = 3676 (31.414 sec)
# INFO:tensorflow:global_step/sec: 0.0321505
# INFO:tensorflow:loss = 0.60577023, step = 3677 (31.107 sec)
# INFO:tensorflow:global_step/sec: 0.0318041
# INFO:tensorflow:loss = 0.882551, step = 3678 (31.440 sec)
# INFO:tensorflow:global_step/sec: 0.0322551
# INFO:tensorflow:loss = 0.4611438, step = 3679 (31.003 sec)
# INFO:tensorflow:global_step/sec: 0.0322225
# INFO:tensorflow:loss = 0.5355147, step = 3680 (31.040 sec)
# INFO:tensorflow:global_step/sec: 0.0318958
# INFO:tensorflow:loss = 0.6298879, step = 3681 (31.348 sec)
# INFO:tensorflow:global_step/sec: 0.0320654
# INFO:tensorflow:loss = 0.6561219, step = 3682 (31.185 sec)
# INFO:tensorflow:global_step/sec: 0.0319456
# INFO:tensorflow:loss = 0.4867417, step = 3683 (31.304 sec)
# INFO:tensorflow:global_step/sec: 0.0321461
# INFO:tensorflow:loss = 0.78306806, step = 3684 (31.107 sec)
# INFO:tensorflow:global_step/sec: 0.03191
# INFO:tensorflow:loss = 1.034633, step = 3685 (31.344 sec)
# INFO:tensorflow:global_step/sec: 0.032071
# INFO:tensorflow:loss = 0.47935933, step = 3686 (31.175 sec)
# INFO:tensorflow:global_step/sec: 0.0321651
# INFO:tensorflow:loss = 0.9400489, step = 3687 (31.089 sec)
# INFO:tensorflow:global_step/sec: 0.0319565
# INFO:tensorflow:loss = 0.4988777, step = 3688 (31.293 sec)
# INFO:tensorflow:global_step/sec: 0.0322062
# INFO:tensorflow:loss = 0.9431108, step = 3689 (31.050 sec)
# INFO:tensorflow:global_step/sec: 0.0322385
# INFO:tensorflow:loss = 0.63898474, step = 3690 (31.019 sec)
# INFO:tensorflow:global_step/sec: 0.0320526
# INFO:tensorflow:loss = 0.68146294, step = 3691 (31.200 sec)
# INFO:tensorflow:global_step/sec: 0.0321054
# INFO:tensorflow:loss = 0.702546, step = 3692 (31.147 sec)
# INFO:tensorflow:global_step/sec: 0.0320835
# INFO:tensorflow:loss = 0.9849515, step = 3693 (31.169 sec)
# INFO:tensorflow:global_step/sec: 0.0321032
# INFO:tensorflow:loss = 0.61806697, step = 3694 (31.151 sec)
# INFO:tensorflow:global_step/sec: 0.0315366
# INFO:tensorflow:loss = 0.69874144, step = 3695 (31.708 sec)
# INFO:tensorflow:Saving checkpoints for 3696 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0316269
# INFO:tensorflow:loss = 0.6166516, step = 3696 (31.621 sec)
# INFO:tensorflow:global_step/sec: 0.0319978
# INFO:tensorflow:loss = 0.8440105, step = 3697 (31.250 sec)
# INFO:tensorflow:global_step/sec: 0.0319127
# INFO:tensorflow:loss = 1.1792109, step = 3698 (31.343 sec)
# INFO:tensorflow:global_step/sec: 0.032142
# INFO:tensorflow:loss = 0.62370616, step = 3699 (31.107 sec)
# INFO:tensorflow:global_step/sec: 0.0316994
# INFO:tensorflow:loss = 0.6240379, step = 3700 (31.545 sec)
# INFO:tensorflow:global_step/sec: 0.0318031
# INFO:tensorflow:loss = 0.6109565, step = 3701 (31.445 sec)
# INFO:tensorflow:global_step/sec: 0.0319666
# INFO:tensorflow:loss = 0.72442126, step = 3702 (31.283 sec)
# INFO:tensorflow:global_step/sec: 0.0319765
# INFO:tensorflow:loss = 0.784283, step = 3703 (31.272 sec)
# INFO:tensorflow:global_step/sec: 0.0319463
# INFO:tensorflow:loss = 0.8212536, step = 3704 (31.307 sec)
# INFO:tensorflow:global_step/sec: 0.0318561
# INFO:tensorflow:loss = 0.42000657, step = 3705 (31.386 sec)
# INFO:tensorflow:global_step/sec: 0.0317412
# INFO:tensorflow:loss = 0.50879186, step = 3706 (31.505 sec)
# INFO:tensorflow:global_step/sec: 0.0315205
# INFO:tensorflow:loss = 0.4510271, step = 3707 (31.726 sec)
# INFO:tensorflow:global_step/sec: 0.0316803
# INFO:tensorflow:loss = 0.35702258, step = 3708 (31.565 sec)
# INFO:tensorflow:global_step/sec: 0.0319593
# INFO:tensorflow:loss = 0.25126725, step = 3709 (31.290 sec)
# INFO:tensorflow:global_step/sec: 0.031877
# INFO:tensorflow:loss = 0.8869317, step = 3710 (31.371 sec)
# INFO:tensorflow:global_step/sec: 0.032012
# INFO:tensorflow:loss = 0.6597205, step = 3711 (31.238 sec)
# INFO:tensorflow:global_step/sec: 0.0317929
# INFO:tensorflow:loss = 0.49498186, step = 3712 (31.457 sec)
# INFO:tensorflow:global_step/sec: 0.0319809
# INFO:tensorflow:loss = 0.43777904, step = 3713 (31.265 sec)
# INFO:tensorflow:global_step/sec: 0.0321591
# INFO:tensorflow:loss = 0.6415132, step = 3714 (31.096 sec)
# INFO:tensorflow:global_step/sec: 0.03211
# INFO:tensorflow:loss = 0.791807, step = 3715 (31.151 sec)
# INFO:tensorflow:Saving checkpoints for 3716 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0316931
# INFO:tensorflow:loss = 0.6365961, step = 3716 (31.545 sec)
# INFO:tensorflow:global_step/sec: 0.0319362
# INFO:tensorflow:loss = 0.5067838, step = 3717 (31.314 sec)
# INFO:tensorflow:global_step/sec: 0.0318189
# INFO:tensorflow:loss = 0.6745594, step = 3718 (31.432 sec)
# INFO:tensorflow:global_step/sec: 0.0321337
# INFO:tensorflow:loss = 0.43805188, step = 3719 (31.115 sec)
# INFO:tensorflow:global_step/sec: 0.031888
# INFO:tensorflow:loss = 0.90802443, step = 3720 (31.366 sec)
# INFO:tensorflow:global_step/sec: 0.0320745
# INFO:tensorflow:loss = 0.6916654, step = 3721 (31.172 sec)
# INFO:tensorflow:global_step/sec: 0.0320897
# INFO:tensorflow:loss = 0.7866984, step = 3722 (31.162 sec)
# INFO:tensorflow:global_step/sec: 0.032049
# INFO:tensorflow:loss = 0.37372938, step = 3723 (31.202 sec)
# INFO:tensorflow:global_step/sec: 0.0319389
# INFO:tensorflow:loss = 0.67723024, step = 3724 (31.310 sec)
# INFO:tensorflow:global_step/sec: 0.0319141
# INFO:tensorflow:loss = 0.30760753, step = 3725 (31.334 sec)
# INFO:tensorflow:global_step/sec: 0.0317907
# INFO:tensorflow:loss = 0.41772166, step = 3726 (31.455 sec)
# INFO:tensorflow:global_step/sec: 0.031561
# INFO:tensorflow:loss = 0.25797388, step = 3727 (31.692 sec)
# INFO:tensorflow:global_step/sec: 0.0313488
# INFO:tensorflow:loss = 0.42550644, step = 3728 (31.893 sec)
# INFO:tensorflow:global_step/sec: 0.0318295
# INFO:tensorflow:loss = 0.70459986, step = 3729 (31.418 sec)
# INFO:tensorflow:global_step/sec: 0.0317994
# INFO:tensorflow:loss = 0.92161834, step = 3730 (31.447 sec)
# INFO:tensorflow:global_step/sec: 0.0318965
# INFO:tensorflow:loss = 0.55396014, step = 3731 (31.352 sec)
# INFO:tensorflow:global_step/sec: 0.0317753
# INFO:tensorflow:loss = 0.6110134, step = 3732 (31.470 sec)
# INFO:tensorflow:global_step/sec: 0.031985
# INFO:tensorflow:loss = 1.2595365, step = 3733 (31.264 sec)
# INFO:tensorflow:global_step/sec: 0.0319719
# INFO:tensorflow:loss = 0.5605835, step = 3734 (31.283 sec)
# INFO:tensorflow:global_step/sec: 0.0325666
# INFO:tensorflow:loss = 0.41125193, step = 3735 (30.706 sec)
# INFO:tensorflow:Saving checkpoints for 3736 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0322721
# INFO:tensorflow:loss = 0.3327938, step = 3736 (30.982 sec)
# INFO:tensorflow:global_step/sec: 0.0323617
# INFO:tensorflow:loss = 0.42642647, step = 3737 (30.906 sec)
# INFO:tensorflow:global_step/sec: 0.0324683
# INFO:tensorflow:loss = 0.7011257, step = 3738 (30.793 sec)
# INFO:tensorflow:global_step/sec: 0.0326481
# INFO:tensorflow:loss = 0.42001063, step = 3739 (30.633 sec)
# INFO:tensorflow:global_step/sec: 0.0325041
# INFO:tensorflow:loss = 0.33492285, step = 3740 (30.762 sec)
# INFO:tensorflow:global_step/sec: 0.0325779
# INFO:tensorflow:loss = 0.6259839, step = 3741 (30.695 sec)
# INFO:tensorflow:global_step/sec: 0.0326307
# INFO:tensorflow:loss = 0.41817436, step = 3742 (30.646 sec)
# INFO:tensorflow:global_step/sec: 0.0325096
# INFO:tensorflow:loss = 0.577451, step = 3743 (30.761 sec)
# INFO:tensorflow:global_step/sec: 0.0325956
# INFO:tensorflow:loss = 0.9055408, step = 3744 (30.678 sec)
# INFO:tensorflow:global_step/sec: 0.0325564
# INFO:tensorflow:loss = 0.8687873, step = 3745 (30.716 sec)
# INFO:tensorflow:global_step/sec: 0.032577
# INFO:tensorflow:loss = 0.65547574, step = 3746 (30.697 sec)
# INFO:tensorflow:global_step/sec: 0.0325654
# INFO:tensorflow:loss = 1.5988237, step = 3747 (30.707 sec)
# INFO:tensorflow:global_step/sec: 0.0325687
# INFO:tensorflow:loss = 0.7081363, step = 3748 (30.704 sec)
# INFO:tensorflow:global_step/sec: 0.0327153
# INFO:tensorflow:loss = 0.8100773, step = 3749 (30.567 sec)
# INFO:tensorflow:global_step/sec: 0.0325763
# INFO:tensorflow:loss = 0.8511915, step = 3750 (30.700 sec)
# INFO:tensorflow:global_step/sec: 0.0326542
# INFO:tensorflow:loss = 0.7065101, step = 3751 (30.626 sec)
# INFO:tensorflow:global_step/sec: 0.0326767
# INFO:tensorflow:loss = 0.9196941, step = 3752 (30.597 sec)
# INFO:tensorflow:global_step/sec: 0.0326829
# INFO:tensorflow:loss = 0.77589065, step = 3753 (30.597 sec)
# INFO:tensorflow:global_step/sec: 0.0326626
# INFO:tensorflow:loss = 0.5445759, step = 3754 (30.616 sec)
# INFO:tensorflow:global_step/sec: 0.0326759
# INFO:tensorflow:loss = 0.83721083, step = 3755 (30.607 sec)
# INFO:tensorflow:Saving checkpoints for 3756 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0324172
# INFO:tensorflow:loss = 0.67156714, step = 3756 (30.844 sec)
# INFO:tensorflow:global_step/sec: 0.0326522
# INFO:tensorflow:loss = 0.2709886, step = 3757 (30.632 sec)
# INFO:tensorflow:global_step/sec: 0.0325525
# INFO:tensorflow:loss = 1.5397308, step = 3758 (30.713 sec)
# INFO:tensorflow:global_step/sec: 0.032561
# INFO:tensorflow:loss = 0.82856655, step = 3759 (30.712 sec)
# INFO:tensorflow:global_step/sec: 0.032595
# INFO:tensorflow:loss = 0.40918365, step = 3760 (30.679 sec)
# INFO:tensorflow:global_step/sec: 0.0325887
# INFO:tensorflow:loss = 1.0473691, step = 3761 (30.685 sec)
# INFO:tensorflow:global_step/sec: 0.0326033
# INFO:tensorflow:loss = 0.7999309, step = 3762 (30.672 sec)
# INFO:tensorflow:global_step/sec: 0.0326937
# INFO:tensorflow:loss = 0.84103125, step = 3763 (30.587 sec)
# INFO:tensorflow:global_step/sec: 0.0326682
# INFO:tensorflow:loss = 0.6553687, step = 3764 (30.615 sec)
# INFO:tensorflow:global_step/sec: 0.0326204
# INFO:tensorflow:loss = 0.7110858, step = 3765 (30.651 sec)
# INFO:tensorflow:global_step/sec: 0.0325402
# INFO:tensorflow:loss = 0.86581784, step = 3766 (30.733 sec)
# INFO:tensorflow:global_step/sec: 0.0326052
# INFO:tensorflow:loss = 0.7715745, step = 3767 (30.672 sec)
# INFO:tensorflow:global_step/sec: 0.0324767
# INFO:tensorflow:loss = 0.730977, step = 3768 (30.788 sec)
# INFO:tensorflow:global_step/sec: 0.0325608
# INFO:tensorflow:loss = 0.2522731, step = 3769 (30.713 sec)
# INFO:tensorflow:global_step/sec: 0.0325166
# INFO:tensorflow:loss = 0.9141194, step = 3770 (30.752 sec)
# INFO:tensorflow:global_step/sec: 0.0326086
# INFO:tensorflow:loss = 0.50995904, step = 3771 (30.676 sec)
# INFO:tensorflow:global_step/sec: 0.0324572
# INFO:tensorflow:loss = 0.4979158, step = 3772 (30.801 sec)
# INFO:tensorflow:global_step/sec: 0.0325283
# INFO:tensorflow:loss = 0.58576024, step = 3773 (30.742 sec)
# INFO:tensorflow:global_step/sec: 0.032463
# INFO:tensorflow:loss = 0.5093911, step = 3774 (30.805 sec)
# INFO:tensorflow:global_step/sec: 0.0324563
# INFO:tensorflow:loss = 0.7358741, step = 3775 (30.817 sec)
# INFO:tensorflow:Saving checkpoints for 3776 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0320615
# INFO:tensorflow:loss = 0.76236486, step = 3776 (31.183 sec)
# INFO:tensorflow:global_step/sec: 0.0325304
# INFO:tensorflow:loss = 0.18045606, step = 3777 (30.741 sec)
# INFO:tensorflow:global_step/sec: 0.0323827
# INFO:tensorflow:loss = 0.47639617, step = 3778 (30.881 sec)
# INFO:tensorflow:global_step/sec: 0.0324626
# INFO:tensorflow:loss = 0.39808026, step = 3779 (30.805 sec)
# INFO:tensorflow:global_step/sec: 0.0325404
# INFO:tensorflow:loss = 0.5644629, step = 3780 (30.731 sec)
# INFO:tensorflow:global_step/sec: 0.0324987
# INFO:tensorflow:loss = 0.2096124, step = 3781 (30.770 sec)
# INFO:tensorflow:global_step/sec: 0.0326146
# INFO:tensorflow:loss = 0.6970496, step = 3782 (30.661 sec)
# INFO:tensorflow:global_step/sec: 0.0325692
# INFO:tensorflow:loss = 0.5557333, step = 3783 (30.704 sec)
# INFO:tensorflow:global_step/sec: 0.0325886
# INFO:tensorflow:loss = 0.89601564, step = 3784 (30.685 sec)
# INFO:tensorflow:global_step/sec: 0.0324495
# INFO:tensorflow:loss = 0.65962005, step = 3785 (30.817 sec)
# INFO:tensorflow:global_step/sec: 0.0325383
# INFO:tensorflow:loss = 0.720544, step = 3786 (30.739 sec)
# INFO:tensorflow:global_step/sec: 0.0323617
# INFO:tensorflow:loss = 0.38266212, step = 3787 (30.898 sec)
# INFO:tensorflow:global_step/sec: 0.0322788
# INFO:tensorflow:loss = 0.75639725, step = 3788 (30.976 sec)
# INFO:tensorflow:global_step/sec: 0.0322922
# INFO:tensorflow:loss = 0.98905563, step = 3789 (30.967 sec)
# INFO:tensorflow:global_step/sec: 0.0323688
# INFO:tensorflow:loss = 0.43389267, step = 3790 (30.894 sec)
# INFO:tensorflow:global_step/sec: 0.0324609
# INFO:tensorflow:loss = 0.6634818, step = 3791 (30.806 sec)
# INFO:tensorflow:global_step/sec: 0.0325176
# INFO:tensorflow:loss = 0.5212546, step = 3792 (30.753 sec)
# INFO:tensorflow:global_step/sec: 0.0324859
# INFO:tensorflow:loss = 0.89604264, step = 3793 (30.782 sec)
# INFO:tensorflow:global_step/sec: 0.0325379
# INFO:tensorflow:loss = 0.5495698, step = 3794 (30.740 sec)
# INFO:tensorflow:global_step/sec: 0.0324741
# INFO:tensorflow:loss = 0.7634794, step = 3795 (30.787 sec)
# INFO:tensorflow:Saving checkpoints for 3796 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0321551
# INFO:tensorflow:loss = 0.3487461, step = 3796 (31.098 sec)
# INFO:tensorflow:global_step/sec: 0.0325502
# INFO:tensorflow:loss = 0.33121586, step = 3797 (30.722 sec)
# INFO:tensorflow:global_step/sec: 0.03247
# INFO:tensorflow:loss = 0.7310935, step = 3798 (30.797 sec)
# INFO:tensorflow:global_step/sec: 0.0323942
# INFO:tensorflow:loss = 1.0870019, step = 3799 (30.870 sec)
# INFO:tensorflow:global_step/sec: 0.0324981
# INFO:tensorflow:loss = 0.78373754, step = 3800 (30.771 sec)
# INFO:tensorflow:global_step/sec: 0.0324769
# INFO:tensorflow:loss = 1.2570281, step = 3801 (30.798 sec)
# INFO:tensorflow:global_step/sec: 0.0325092
# INFO:tensorflow:loss = 0.6448246, step = 3802 (30.753 sec)
# INFO:tensorflow:global_step/sec: 0.0325565
# INFO:tensorflow:loss = 1.1685603, step = 3803 (30.716 sec)
# INFO:tensorflow:global_step/sec: 0.0325121
# INFO:tensorflow:loss = 0.81003225, step = 3804 (30.758 sec)
# INFO:tensorflow:global_step/sec: 0.03253
# INFO:tensorflow:loss = 0.96370876, step = 3805 (30.741 sec)
# INFO:tensorflow:global_step/sec: 0.032565
# INFO:tensorflow:loss = 0.8787125, step = 3806 (30.712 sec)
# INFO:tensorflow:global_step/sec: 0.0324121
# INFO:tensorflow:loss = 0.8912161, step = 3807 (30.847 sec)
# INFO:tensorflow:global_step/sec: 0.0323694
# INFO:tensorflow:loss = 0.71205986, step = 3808 (30.893 sec)
# INFO:tensorflow:global_step/sec: 0.0324386
# INFO:tensorflow:loss = 0.7383181, step = 3809 (30.827 sec)
# INFO:tensorflow:global_step/sec: 0.0325895
# INFO:tensorflow:loss = 0.37654766, step = 3810 (30.684 sec)
# INFO:tensorflow:global_step/sec: 0.0324757
# INFO:tensorflow:loss = 0.9918935, step = 3811 (30.793 sec)
# INFO:tensorflow:global_step/sec: 0.032597
# INFO:tensorflow:loss = 0.8776374, step = 3812 (30.677 sec)
# INFO:tensorflow:global_step/sec: 0.0325715
# INFO:tensorflow:loss = 0.22468626, step = 3813 (30.713 sec)
# INFO:tensorflow:global_step/sec: 0.0325447
# INFO:tensorflow:loss = 0.6761281, step = 3814 (30.715 sec)
# INFO:tensorflow:global_step/sec: 0.0325356
# INFO:tensorflow:loss = 0.3693997, step = 3815 (30.736 sec)
# INFO:tensorflow:Saving checkpoints for 3816 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0323411
# INFO:tensorflow:loss = 0.6197375, step = 3816 (30.921 sec)
# INFO:tensorflow:global_step/sec: 0.0325871
# INFO:tensorflow:loss = 0.56614053, step = 3817 (30.695 sec)
# INFO:tensorflow:global_step/sec: 0.032328
# INFO:tensorflow:loss = 1.014682, step = 3818 (30.925 sec)
# INFO:tensorflow:global_step/sec: 0.0321005
# INFO:tensorflow:loss = 1.0636472, step = 3819 (31.152 sec)
# INFO:tensorflow:global_step/sec: 0.0322106
# INFO:tensorflow:loss = 0.84597635, step = 3820 (31.045 sec)
# ...
# INFO:tensorflow:global_step/sec: 0.0325615
# INFO:tensorflow:loss = 0.9346193, step = 4282 (30.718 sec)
# INFO:tensorflow:global_step/sec: 0.0324877
# INFO:tensorflow:loss = 1.0079094, step = 4283 (30.780 sec)
# INFO:tensorflow:Saving checkpoints for 4284 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0321014
# INFO:tensorflow:loss = 1.0427072, step = 4284 (31.145 sec)
# INFO:tensorflow:global_step/sec: 0.0325354
# INFO:tensorflow:loss = 0.7696093, step = 4285 (30.736 sec)
# INFO:tensorflow:global_step/sec: 0.032276
# INFO:tensorflow:loss = 0.8034867, step = 4286 (30.983 sec)
# INFO:tensorflow:global_step/sec: 0.032145
# INFO:tensorflow:loss = 0.82011354, step = 4287 (31.109 sec)
# INFO:tensorflow:global_step/sec: 0.0320566
# INFO:tensorflow:loss = 0.3741207, step = 4288 (31.200 sec)
# INFO:tensorflow:global_step/sec: 0.032408
# INFO:tensorflow:loss = 0.4239429, step = 4289 (30.858 sec)
# INFO:tensorflow:global_step/sec: 0.0324311
# INFO:tensorflow:loss = 0.948929, step = 4290 (30.834 sec)
# INFO:tensorflow:global_step/sec: 0.0323654
# INFO:tensorflow:loss = 0.42796907, step = 4291 (30.898 sec)
# INFO:tensorflow:global_step/sec: 0.032394
# INFO:tensorflow:loss = 0.60181296, step = 4292 (30.866 sec)
# INFO:tensorflow:global_step/sec: 0.0319635
# INFO:tensorflow:loss = 0.8780484, step = 4293 (31.282 sec)
# INFO:tensorflow:global_step/sec: 0.0323246
# INFO:tensorflow:loss = 0.9311922, step = 4294 (30.936 sec)
# INFO:tensorflow:global_step/sec: 0.0325283
# INFO:tensorflow:loss = 0.6889576, step = 4295 (30.744 sec)
# INFO:tensorflow:global_step/sec: 0.0325191
# INFO:tensorflow:loss = 0.55336446, step = 4296 (30.750 sec)
# INFO:tensorflow:global_step/sec: 0.0324137
# INFO:tensorflow:loss = 0.78194404, step = 4297 (30.851 sec)
# INFO:tensorflow:global_step/sec: 0.0325146
# INFO:tensorflow:loss = 0.6452939, step = 4298 (30.757 sec)
# INFO:tensorflow:global_step/sec: 0.0325097
# INFO:tensorflow:loss = 0.5827561, step = 4299 (30.765 sec)
# INFO:tensorflow:global_step/sec: 0.0326216
# INFO:tensorflow:loss = 0.36058506, step = 4300 (30.648 sec)
# INFO:tensorflow:global_step/sec: 0.0326012
# INFO:tensorflow:loss = 0.7601902, step = 4301 (30.674 sec)
# INFO:tensorflow:global_step/sec: 0.0326067
# INFO:tensorflow:loss = 0.93455267, step = 4302 (30.673 sec)
# INFO:tensorflow:global_step/sec: 0.0325553
# INFO:tensorflow:loss = 0.31421226, step = 4303 (30.712 sec)
# INFO:tensorflow:Saving checkpoints for 4304 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0321819
# INFO:tensorflow:loss = 0.49101838, step = 4304 (31.073 sec)
# INFO:tensorflow:global_step/sec: 0.032458
# INFO:tensorflow:loss = 0.704823, step = 4305 (30.810 sec)
# INFO:tensorflow:global_step/sec: 0.0322209
# INFO:tensorflow:loss = 0.7555096, step = 4306 (31.037 sec)
# INFO:tensorflow:global_step/sec: 0.0321626
# INFO:tensorflow:loss = 0.5942343, step = 4307 (31.091 sec)
# INFO:tensorflow:global_step/sec: 0.0324646
# INFO:tensorflow:loss = 0.55722046, step = 4308 (30.802 sec)
# INFO:tensorflow:global_step/sec: 0.03217
# INFO:tensorflow:loss = 0.5942447, step = 4309 (31.085 sec)
# INFO:tensorflow:global_step/sec: 0.0322923
# INFO:tensorflow:loss = 0.7003455, step = 4310 (30.967 sec)
# INFO:tensorflow:global_step/sec: 0.0323391
# INFO:tensorflow:loss = 0.38687712, step = 4311 (30.929 sec)
# INFO:tensorflow:global_step/sec: 0.0324293
# INFO:tensorflow:loss = 0.4666647, step = 4312 (30.830 sec)
# INFO:tensorflow:global_step/sec: 0.0325013
# INFO:tensorflow:loss = 0.3050298, step = 4313 (30.771 sec)
# INFO:tensorflow:global_step/sec: 0.0322489
# INFO:tensorflow:loss = 0.7556769, step = 4314 (31.014 sec)
# INFO:tensorflow:global_step/sec: 0.0324962
# INFO:tensorflow:loss = 0.32348278, step = 4315 (30.767 sec)
# INFO:tensorflow:global_step/sec: 0.0324102
# INFO:tensorflow:loss = 0.8463413, step = 4316 (30.852 sec)
# INFO:tensorflow:global_step/sec: 0.0324275
# INFO:tensorflow:loss = 0.58361703, step = 4317 (30.838 sec)
# INFO:tensorflow:global_step/sec: 0.0323252
# INFO:tensorflow:loss = 0.8092518, step = 4318 (30.941 sec)
# INFO:tensorflow:global_step/sec: 0.0325157
# INFO:tensorflow:loss = 1.1213102, step = 4319 (30.750 sec)
# INFO:tensorflow:global_step/sec: 0.032655
# INFO:tensorflow:loss = 0.7507757, step = 4320 (30.627 sec)
# INFO:tensorflow:global_step/sec: 0.0325886
# INFO:tensorflow:loss = 0.66495824, step = 4321 (30.682 sec)
# INFO:tensorflow:global_step/sec: 0.0325969
# INFO:tensorflow:loss = 0.33944887, step = 4322 (30.678 sec)
# INFO:tensorflow:global_step/sec: 0.0325843
# INFO:tensorflow:loss = 0.67580014, step = 4323 (30.690 sec)
# INFO:tensorflow:Saving checkpoints for 4324 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0319901
# INFO:tensorflow:loss = 1.1286395, step = 4324 (31.260 sec)
# INFO:tensorflow:global_step/sec: 0.0324856
# INFO:tensorflow:loss = 0.8274357, step = 4325 (30.783 sec)
# INFO:tensorflow:global_step/sec: 0.0324332
# INFO:tensorflow:loss = 0.5557711, step = 4326 (30.835 sec)
# INFO:tensorflow:global_step/sec: 0.0324375
# INFO:tensorflow:loss = 0.6415699, step = 4327 (30.826 sec)
# INFO:tensorflow:global_step/sec: 0.0325053
# INFO:tensorflow:loss = 0.9987375, step = 4328 (30.764 sec)
# INFO:tensorflow:global_step/sec: 0.0322601
# INFO:tensorflow:loss = 0.65190613, step = 4329 (30.999 sec)
# INFO:tensorflow:global_step/sec: 0.0322721
# INFO:tensorflow:loss = 0.7204528, step = 4330 (30.986 sec)
# INFO:tensorflow:global_step/sec: 0.0324704
# INFO:tensorflow:loss = 0.5914587, step = 4331 (30.802 sec)
# INFO:tensorflow:global_step/sec: 0.0323667
# INFO:tensorflow:loss = 1.1909541, step = 4332 (30.891 sec)
# INFO:tensorflow:global_step/sec: 0.0325408
# INFO:tensorflow:loss = 0.5306302, step = 4333 (30.730 sec)
# INFO:tensorflow:global_step/sec: 0.0323088
# INFO:tensorflow:loss = 1.1453773, step = 4334 (30.953 sec)
# INFO:tensorflow:global_step/sec: 0.0324622
# INFO:tensorflow:loss = 0.85630953, step = 4335 (30.804 sec)
# INFO:tensorflow:global_step/sec: 0.0323307
# INFO:tensorflow:loss = 0.5815501, step = 4336 (30.931 sec)
# INFO:tensorflow:global_step/sec: 0.0323225
# INFO:tensorflow:loss = 0.42284542, step = 4337 (30.946 sec)
# INFO:tensorflow:global_step/sec: 0.0325249
# INFO:tensorflow:loss = 0.88905466, step = 4338 (30.742 sec)
# INFO:tensorflow:global_step/sec: 0.0324964
# INFO:tensorflow:loss = 0.36100203, step = 4339 (30.768 sec)
# INFO:tensorflow:global_step/sec: 0.0324055
# INFO:tensorflow:loss = 0.59040534, step = 4340 (30.867 sec)
# INFO:tensorflow:global_step/sec: 0.0324066
# INFO:tensorflow:loss = 0.5152555, step = 4341 (30.852 sec)
# INFO:tensorflow:global_step/sec: 0.0324299
# INFO:tensorflow:loss = 0.7549207, step = 4342 (30.834 sec)
# INFO:tensorflow:global_step/sec: 0.0324575
# INFO:tensorflow:loss = 0.57844126, step = 4343 (30.810 sec)
# INFO:tensorflow:Saving checkpoints for 4344 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0319175
# INFO:tensorflow:loss = 0.4877363, step = 4344 (31.332 sec)
# INFO:tensorflow:global_step/sec: 0.0324749
# INFO:tensorflow:loss = 0.6794826, step = 4345 (30.792 sec)
# INFO:tensorflow:global_step/sec: 0.0325085
# INFO:tensorflow:loss = 0.60551035, step = 4346 (30.761 sec)
# INFO:tensorflow:global_step/sec: 0.0324689
# INFO:tensorflow:loss = 0.5768689, step = 4347 (30.799 sec)
# INFO:tensorflow:global_step/sec: 0.0324869
# INFO:tensorflow:loss = 0.7460102, step = 4348 (30.784 sec)
# INFO:tensorflow:global_step/sec: 0.0324199
# INFO:tensorflow:loss = 0.487629, step = 4349 (30.849 sec)
# INFO:tensorflow:global_step/sec: 0.0323032
# INFO:tensorflow:loss = 0.63600004, step = 4350 (30.950 sec)
# INFO:tensorflow:global_step/sec: 0.0322144
# INFO:tensorflow:loss = 0.7179767, step = 4351 (31.042 sec)
# INFO:tensorflow:global_step/sec: 0.032447
# INFO:tensorflow:loss = 1.2660654, step = 4352 (30.819 sec)
# INFO:tensorflow:global_step/sec: 0.0324272
# INFO:tensorflow:loss = 0.7515397, step = 4353 (30.838 sec)
# INFO:tensorflow:global_step/sec: 0.0322819
# INFO:tensorflow:loss = 0.565286, step = 4354 (30.978 sec)
# INFO:tensorflow:global_step/sec: 0.032355
# INFO:tensorflow:loss = 0.43479675, step = 4355 (30.906 sec)
# INFO:tensorflow:global_step/sec: 0.0325758
# INFO:tensorflow:loss = 0.8291979, step = 4356 (30.698 sec)
# INFO:tensorflow:global_step/sec: 0.0323581
# INFO:tensorflow:loss = 0.47723103, step = 4357 (30.904 sec)
# INFO:tensorflow:global_step/sec: 0.0324805
# INFO:tensorflow:loss = 0.6299517, step = 4358 (30.788 sec)
# INFO:tensorflow:global_step/sec: 0.0324318
# INFO:tensorflow:loss = 0.7494106, step = 4359 (30.834 sec)
# INFO:tensorflow:global_step/sec: 0.0324095
# INFO:tensorflow:loss = 0.65033436, step = 4360 (30.856 sec)
# INFO:tensorflow:global_step/sec: 0.0322777
# INFO:tensorflow:loss = 0.9341885, step = 4361 (30.981 sec)
# INFO:tensorflow:global_step/sec: 0.0324307
# INFO:tensorflow:loss = 0.6421895, step = 4362 (30.834 sec)
# INFO:tensorflow:global_step/sec: 0.0324659
# INFO:tensorflow:loss = 0.43303147, step = 4363 (30.801 sec)
# INFO:tensorflow:Saving checkpoints for 4364 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0321225
# INFO:tensorflow:loss = 0.66609013, step = 4364 (31.132 sec)
# INFO:tensorflow:global_step/sec: 0.0324642
# INFO:tensorflow:loss = 0.7943265, step = 4365 (30.809 sec)
# INFO:tensorflow:global_step/sec: 0.0325134
# INFO:tensorflow:loss = 0.6565086, step = 4366 (30.750 sec)
# INFO:tensorflow:global_step/sec: 0.0324652
# INFO:tensorflow:loss = 0.44739407, step = 4367 (30.802 sec)
# INFO:tensorflow:global_step/sec: 0.0323917
# INFO:tensorflow:loss = 0.30513406, step = 4368 (30.872 sec)
# INFO:tensorflow:global_step/sec: 0.0326019
# INFO:tensorflow:loss = 0.41295522, step = 4369 (30.673 sec)
# INFO:tensorflow:global_step/sec: 0.0325102
# INFO:tensorflow:loss = 0.7737589, step = 4370 (30.760 sec)
# INFO:tensorflow:global_step/sec: 0.0325227
# INFO:tensorflow:loss = 1.0214736, step = 4371 (30.750 sec)
# INFO:tensorflow:global_step/sec: 0.0324176
# INFO:tensorflow:loss = 0.57221854, step = 4372 (30.846 sec)
# INFO:tensorflow:global_step/sec: 0.0324968
# INFO:tensorflow:loss = 0.29853073, step = 4373 (30.771 sec)
# INFO:tensorflow:global_step/sec: 0.0324415
# INFO:tensorflow:loss = 0.96728104, step = 4374 (30.825 sec)
# INFO:tensorflow:global_step/sec: 0.0325109
# INFO:tensorflow:loss = 0.6735164, step = 4375 (30.759 sec)
# INFO:tensorflow:global_step/sec: 0.0324804
# INFO:tensorflow:loss = 1.077282, step = 4376 (30.788 sec)
# INFO:tensorflow:global_step/sec: 0.0325903
# INFO:tensorflow:loss = 0.46260816, step = 4377 (30.684 sec)
# INFO:tensorflow:global_step/sec: 0.0325583
# INFO:tensorflow:loss = 0.7002777, step = 4378 (30.714 sec)
# INFO:tensorflow:global_step/sec: 0.032607
# INFO:tensorflow:loss = 0.401961, step = 4379 (30.668 sec)
# INFO:tensorflow:global_step/sec: 0.0325274
# INFO:tensorflow:loss = 0.35962135, step = 4380 (30.743 sec)
# INFO:tensorflow:global_step/sec: 0.0326207
# INFO:tensorflow:loss = 0.72759116, step = 4381 (30.655 sec)
# INFO:tensorflow:global_step/sec: 0.0325028
# INFO:tensorflow:loss = 0.6412627, step = 4382 (30.766 sec)
# INFO:tensorflow:global_step/sec: 0.0324338
# INFO:tensorflow:loss = 0.3769059, step = 4383 (30.833 sec)
# INFO:tensorflow:Saving checkpoints for 4384 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0321959
# INFO:tensorflow:loss = 0.7777709, step = 4384 (31.065 sec)
# INFO:tensorflow:global_step/sec: 0.0316109
# INFO:tensorflow:loss = 1.1169498, step = 4385 (31.629 sec)
# INFO:tensorflow:global_step/sec: 0.0311815
# INFO:tensorflow:loss = 0.7155211, step = 4386 (32.070 sec)
# INFO:tensorflow:global_step/sec: 0.0307551
# INFO:tensorflow:loss = 0.13218808, step = 4387 (32.515 sec)
# INFO:tensorflow:global_step/sec: 0.0313794
# INFO:tensorflow:loss = 0.8199315, step = 4388 (31.869 sec)
# INFO:tensorflow:global_step/sec: 0.031562
# INFO:tensorflow:loss = 0.47702876, step = 4389 (31.682 sec)
# INFO:tensorflow:global_step/sec: 0.0324666
# INFO:tensorflow:loss = 0.50360966, step = 4390 (30.801 sec)
# INFO:tensorflow:global_step/sec: 0.0325315
# INFO:tensorflow:loss = 0.7415481, step = 4391 (30.740 sec)
# INFO:tensorflow:global_step/sec: 0.0322482
# INFO:tensorflow:loss = 0.75011045, step = 4392 (31.010 sec)
# INFO:tensorflow:global_step/sec: 0.0317839
# INFO:tensorflow:loss = 0.65002406, step = 4393 (31.464 sec)
# INFO:tensorflow:global_step/sec: 0.0315201
# INFO:tensorflow:loss = 0.634338, step = 4394 (31.724 sec)
# INFO:tensorflow:global_step/sec: 0.0320513
# INFO:tensorflow:loss = 0.72082317, step = 4395 (31.204 sec)
# INFO:tensorflow:global_step/sec: 0.0316594
# INFO:tensorflow:loss = 0.2079554, step = 4396 (31.583 sec)
# INFO:tensorflow:global_step/sec: 0.0314122
# INFO:tensorflow:loss = 0.37590042, step = 4397 (31.834 sec)
# INFO:tensorflow:global_step/sec: 0.0310915
# INFO:tensorflow:loss = 0.7879649, step = 4398 (32.169 sec)
# INFO:tensorflow:global_step/sec: 0.0309327
# INFO:tensorflow:loss = 1.0280275, step = 4399 (32.330 sec)
# INFO:tensorflow:global_step/sec: 0.0308292
# INFO:tensorflow:loss = 0.5829272, step = 4400 (32.430 sec)
# INFO:tensorflow:global_step/sec: 0.0321677
# INFO:tensorflow:loss = 0.43638715, step = 4401 (31.087 sec)
# INFO:tensorflow:global_step/sec: 0.0323598
# INFO:tensorflow:loss = 0.83560085, step = 4402 (30.910 sec)
# INFO:tensorflow:Saving checkpoints for 4403 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0321161
# INFO:tensorflow:loss = 0.73479176, step = 4403 (31.129 sec)
# INFO:tensorflow:global_step/sec: 0.0324182
# INFO:tensorflow:loss = 0.41282392, step = 4404 (30.852 sec)
# INFO:tensorflow:global_step/sec: 0.0324145
# INFO:tensorflow:loss = 0.80967075, step = 4405 (30.847 sec)
# INFO:tensorflow:global_step/sec: 0.0324913
# INFO:tensorflow:loss = 0.34992853, step = 4406 (30.777 sec)
# INFO:tensorflow:global_step/sec: 0.0324625
# INFO:tensorflow:loss = 0.534759, step = 4407 (30.805 sec)
# INFO:tensorflow:global_step/sec: 0.0326048
# INFO:tensorflow:loss = 1.0137514, step = 4408 (30.670 sec)
# INFO:tensorflow:global_step/sec: 0.0326079
# INFO:tensorflow:loss = 0.5247685, step = 4409 (30.675 sec)
# INFO:tensorflow:global_step/sec: 0.0325696
# INFO:tensorflow:loss = 0.47669592, step = 4410 (30.700 sec)
# INFO:tensorflow:global_step/sec: 0.0325629
# INFO:tensorflow:loss = 0.4942971, step = 4411 (30.712 sec)
# INFO:tensorflow:global_step/sec: 0.0326415
# INFO:tensorflow:loss = 1.4185776, step = 4412 (30.629 sec)
# INFO:tensorflow:global_step/sec: 0.032598
# INFO:tensorflow:loss = 0.82468385, step = 4413 (30.683 sec)
# INFO:tensorflow:global_step/sec: 0.0325378
# INFO:tensorflow:loss = 0.57154256, step = 4414 (30.727 sec)
# INFO:tensorflow:global_step/sec: 0.0324804
# INFO:tensorflow:loss = 0.27065432, step = 4415 (30.788 sec)
# INFO:tensorflow:global_step/sec: 0.0325094
# INFO:tensorflow:loss = 0.54309386, step = 4416 (30.760 sec)
# INFO:tensorflow:global_step/sec: 0.0326347
# INFO:tensorflow:loss = 0.7138115, step = 4417 (30.642 sec)
# INFO:tensorflow:global_step/sec: 0.0326113
# INFO:tensorflow:loss = 1.2614286, step = 4418 (30.665 sec)
# INFO:tensorflow:global_step/sec: 0.032411
# INFO:tensorflow:loss = 0.24283075, step = 4419 (30.853 sec)
# INFO:tensorflow:global_step/sec: 0.0325516
# INFO:tensorflow:loss = 0.73897904, step = 4420 (30.721 sec)
# INFO:tensorflow:Saving checkpoints for 4420 into denseNet3d_result/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.73897904.
# INFO:tensorflow:Calling model_fn.
# Build 3D DenseNet-BC model with 3 blocks, 2 bottleneck layers and 2 composite layers each.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-07-19-09:46:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from denseNet3d_result/model.ckpt-4420
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [3/30]
# INFO:tensorflow:Evaluation [6/30]
# INFO:tensorflow:Evaluation [9/30]
# INFO:tensorflow:Evaluation [12/30]
# INFO:tensorflow:Evaluation [15/30]
# INFO:tensorflow:Evaluation [18/30]
# INFO:tensorflow:Evaluation [21/30]
# INFO:tensorflow:Evaluation [24/30]
# INFO:tensorflow:Evaluation [27/30]
# INFO:tensorflow:Evaluation [30/30]
# INFO:tensorflow:Finished evaluation at 2019-07-19-09:51:47
# INFO:tensorflow:Saving dict for global step 4420: eval_accuracy = 0.41, global_step = 4420, loss = 1.9266256
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4420: denseNet3d_result/model.ckpt-4420
# {'eval_accuracy': 0.41, 'global_step': 4420, 'loss': 1.9266256}
